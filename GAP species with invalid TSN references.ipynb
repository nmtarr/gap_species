# %% [markdown]
# This notebook queries the Taxonomic Information Registry for cases where a registered GAP species has a Taxonomic Serial Number (TSN) identifier that is shown as invalid in the Integrated Taxonomic Information System (ITIS). The GAP-TSN connection occurred at a point in time when the taxonomic information in ITIS was considered to be correct. Species were modeled according to characteristics of the taxon at that point in time. It may or may not be valid to follow the taxonomic updates in ITIS without further review by the modeling team to determine how that transition should occur.

# %%
import requests,configparser
from IPython.display import display

# %%
# Get API keys and any other config details from a file that is external to the code.
config = configparser.RawConfigParser()
config.read_file(open(r'../config/stuff.py'))

# %%
# Build base URL with API key using input from the external config.
def getBaseURL():
    gc2APIKey = config.get('apiKeys','apiKey_GC2_BCB').replace('"','')
    apiBaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?key="+gc2APIKey
    return apiBaseURL

# %%
r = requests.get(getBaseURL()+"&q=SELECT registration->'ITIS_TSN' AS gaptsn, registration->'GAP_CommonName' AS gapcommonname, registration->'GAP_SpeciesCode' AS gapspeciescode, registration->'GAP_ScientificName' AS gapscientificname, registration->'ScienceBaseItemID' AS sbid, itis->'tsn' AS itistsn, itis->'acceptedTSN' AS acceptedtsn, itis->'usage' AS usage FROM tir.tir2 WHERE registration->'DOI' LIKE 'doi:%' AND itis->'usage' = 'invalid'").json()

print ("Total Records: "+str(len(r["features"])))
print ("--------")

for feature in r["features"]:
    print (feature["properties"]["gapspeciescode"]+" - "+feature["properties"]["gapscientificname"]+"("+feature["properties"]["gapcommonname"]+")")
    print ("https://www.sciencebase.gov/catalog/item/"+feature["properties"]["sbid"])
    print ("GAP TSN: "+str(feature["properties"]["gaptsn"])+" (usage: "+feature["properties"]["usage"]+")")
    print ("Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:"+feature["properties"]["acceptedtsn"])
    print ("----")
# Out:
# Total Records: 128
# --------
# bNOPAx - Parula americana(Northern Parula)
# https://www.sciencebase.gov/catalog/item/58fa518ee4b0b7ea54525232
# GAP TSN: 178868 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950033
# ----
# rCOSKx - Plestiodon anthracinus(Coal Skink)
# https://www.sciencebase.gov/catalog/item/58fe0f97e4b007492829463c
# GAP TSN: 208882 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173962
# ----
# rFLSKx - Plestiodon tetragrammus(Four-lined Skink)
# https://www.sciencebase.gov/catalog/item/58fe15bae4b0f87f0854acc0
# GAP TSN: 208908 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173971
# ----
# aSNTOx - Ollotis alvaria(Sonoran Desert Toad)
# https://www.sciencebase.gov/catalog/item/58fa42e6e4b0b7ea54524b53
# GAP TSN: 775976 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:773562
# ----
# bBLPWx - Dendroica striata(Blackpoll Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4624e4b0b7ea54524d48
# GAP TSN: 178913 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950041
# ----
# rPRSKx - Plestiodon septentrionalis(Prairie Skink)
# https://www.sciencebase.gov/catalog/item/58fe20c8e4b0f87f0854ae2f
# GAP TSN: 208900 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173969
# ----
# bBTBWx - Dendroica caerulescens(Black-throated Blue Warbler)
# https://www.sciencebase.gov/catalog/item/58fa46f7e4b0b7ea54524dc0
# GAP TSN: 178888 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950042
# ----
# bBACSx - Aimophila aestivalis(Bachman's Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa4505e4b0b7ea54524c9e
# GAP TSN: 179386 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997733
# ----
# bFRGUx - Leucophaeus pipixcan(Franklin's Gull)
# https://www.sciencebase.gov/catalog/item/58fa4aede4b0b7ea54524f9c
# GAP TSN: 176838 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824082
# ----
# bWILLx - Tringa semipalmata(Willet)
# https://www.sciencebase.gov/catalog/item/58fa5cdae4b0b7ea545255c3
# GAP TSN: 176638 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824147
# ----
# bBRTEx - Onychoprion anaethetus(Bridled Tern)
# https://www.sciencebase.gov/catalog/item/58fa46dce4b0b7ea54524db0
# GAP TSN: 176897 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824104
# ----
# bCAWAx - Wilsonia canadensis(Canada Warbler)
# https://www.sciencebase.gov/catalog/item/58fa483fe4b0b7ea54524e60
# GAP TSN: 178977 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950079
# ----
# mIGSQe - Spermophilus brunneus endemicus(Southern Idaho Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6b07e4b0b7ea545258ed
# GAP TSN: 180150 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930316
# ----
# rMOSKx - Plestiodon egregius(Mole Skink)
# https://www.sciencebase.gov/catalog/item/58fe1c1fe4b0f87f0854ada3
# GAP TSN: 208885 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173965
# ----
# mIGSQb - Spermophilus brunneus brunneus(Northern Idaho Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6af0e4b0b7ea545258ea
# GAP TSN: 180150 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930316
# ----
# bBOCHx - Poecile hudsonica(Boreal Chickadee)
# https://www.sciencebase.gov/catalog/item/58fa4677e4b0b7ea54524d78
# GAP TSN: 726112 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:554386
# ----
# bBRJAx - Cyanocorax morio(Brown Jay)
# https://www.sciencebase.gov/catalog/item/58fa46ace4b0b7ea54524d96
# GAP TSN: 179715 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:562548
# ----
# mSRBVx - Myodes gapperi(Southern Red-backed Vole)
# https://www.sciencebase.gov/catalog/item/58fa7bb7e4b0b7ea54525b72
# GAP TSN: 180294 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:970612
# ----
# bCMWAx - Dendroica tigrina(Cape May Warbler)
# https://www.sciencebase.gov/catalog/item/58fa48cae4b0b7ea54524ea2
# GAP TSN: 178887 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950031
# ----
# mCGGSx - Spermophilus saturatus(Cascade Golden-mantled Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6399e4b0b7ea545257aa
# GAP TSN: 180158 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930304
# ----
# bKEWAx - Oporornis formosus(Kentucky Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4e18e4b0b7ea545250ec
# GAP TSN: 178937 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950025
# ----
# mWEPIx - Pipistrellus hesperus(Western Pipistrelle)
# https://www.sciencebase.gov/catalog/item/58fa7f39e4b0b7ea54525bea
# GAP TSN: 180024 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:947298
# ----
# bSAGSx - Amphispiza belli(Sage Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa5693e4b0b7ea545253c9
# GAP TSN: 179402 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997724
# ----
# rCCHWx - Aspidoscelis neotesselata(Colorado Checkered Whiptail)
# https://www.sciencebase.gov/catalog/item/58fe0d74e4b00749282945f7
# GAP TSN: 683028 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:174026
# ----
# mMGVOx - Microtus mogollonensis(Mogollon Vole)
# https://www.sciencebase.gov/catalog/item/58fa6ef3e4b0b7ea54525989
# GAP TSN: 552480 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:180308
# ----
# rCOACx - Coluber flagellum(Coachwhip)
# https://www.sciencebase.gov/catalog/item/58fe0f38e4b0074928294633
# GAP TSN: 209320 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:174238
# ----
# aGBSAx - Haideotriton wallacei(Georgia Blind Salamander)
# https://www.sciencebase.gov/catalog/item/58fa404ae4b0b7ea54524983
# GAP TSN: 173717 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:775913
# ----
# bBWWAx - Vermivora pinus(Blue-winged Warbler)
# https://www.sciencebase.gov/catalog/item/58fa477ee4b0b7ea54524e03
# GAP TSN: 178853 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950045
# ----
# bLETEa - Sternula antillarum athalassos(Interior Least Tern)
# https://www.sciencebase.gov/catalog/item/58fa4f39e4b0b7ea54525160
# GAP TSN: 176923 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824127
# ----
# rEMDTx - Kinosternon subrubrum(Eastern Mud Turtle)
# https://www.sciencebase.gov/catalog/item/58fe14cae4b0f87f0854aca2
# GAP TSN: 173763 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:949136
# ----
# bHOREx - Carduelis hornemanni(Hoary Redpoll)
# https://www.sciencebase.gov/catalog/item/58fa4db2e4b0b7ea545250c4
# GAP TSN: 179231 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179238
# ----
# mMOSQx - Spermophilus mohavensis(Mohave Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6fafe4b0b7ea545259a7
# GAP TSN: 180156 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930310
# ----
# rANLIx - Xantusia arizonae(Arizona Night Lizard)
# https://www.sciencebase.gov/catalog/item/58fe0a83e4b0074928294571
# GAP TSN: 914104 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:208991
# ----
# bLIGUx - Hydrocoloeus minutus(Little Gull)
# https://www.sciencebase.gov/catalog/item/58fa4f6be4b0b7ea54525173
# GAP TSN: 176840 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824065
# ----
# bPIWAx - Dendroica pinus(Pine Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5354e4b0b7ea545252c5
# GAP TSN: 178914 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950045
# ----
# bPUFIx - Carpodacus purpureus(Purple Finch)
# https://www.sciencebase.gov/catalog/item/58fa53bde4b0b7ea545252e6
# GAP TSN: 179186 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997803
# ----
# bMOWAx - Oporornis philadelphia(Mourning Warbler)
# https://www.sciencebase.gov/catalog/item/58fa50f2e4b0b7ea545251fe
# GAP TSN: 178939 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950024
# ----
# bCOLWx - Vermivora crissalis(Colima Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4932e4b0b7ea54524ece
# GAP TSN: 178865 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950016
# ----
# mWYSQn - Urocitellus elegans nevadensis(Wyoming Ground Squirrel nevadensis)
# https://www.sciencebase.gov/catalog/item/58fe0968e4b007492829451a
# GAP TSN: 180152 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930319
# ----
# bLETEx - Sternula antillarum(Least Tern)
# https://www.sciencebase.gov/catalog/item/58fa4f4ee4b0b7ea54525168
# GAP TSN: 176923 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824127
# ----
# rSUCOx - Pseudemys suwanniensis(Suwannee Cooter)
# https://www.sciencebase.gov/catalog/item/58fe2a0ae4b0f87f0854af54
# GAP TSN: 668673 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:208646
# ----
# mPGSQx - Spermophilus mollis(Piute Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa749be4b0b7ea54525a64
# GAP TSN: 552504 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930320
# ----
# bBLBWx - Dendroica fusca(Blackburnian Warbler)
# https://www.sciencebase.gov/catalog/item/58fa45fae4b0b7ea54524d31
# GAP TSN: 178904 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950037
# ----
# mTOVOp - Microtus townsendii pugeti(Shaw Island Vole)
# https://www.sciencebase.gov/catalog/item/58fa7db0e4b0b7ea54525bb4
# GAP TSN: 972933 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:180316
# ----
# bNAWAx - Vermivora ruficapilla(Nashville Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5114e4b0b7ea5452520b
# GAP TSN: 178861 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950018
# ----
# bHEWAx - Dendroica occidentalis(Hermit Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4d77e4b0b7ea545250ad
# GAP TSN: 178902 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950059
# ----
# bLETEb - Sternula antillarum browni(California Least Tern)
# https://www.sciencebase.gov/catalog/item/58fa4f45e4b0b7ea54525164
# GAP TSN: 176923 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824127
# ----
# aCANEx - Rhinella marinus(Cane Toad)
# https://www.sciencebase.gov/catalog/item/58fa3f66e4b0b7ea545248bc
# GAP TSN: 776032 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:773729
# ----
# bOCWAx - Vermivora celata(Orange-crowned Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5230e4b0b7ea54525268
# GAP TSN: 178856 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950015
# ----
# bTEWAx - Vermivora peregrina(Tennessee Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5a06e4b0b7ea545254e6
# GAP TSN: 178855 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950014
# ----
# bYWARx - Dendroica petechia(Yellow Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5f48e4b0b7ea54525691
# GAP TSN: 178878 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950039
# ----
# mGMGSb - Spermophilus lateralis bernardinus(San Bernardino Golden-mantled Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6931e4b0b7ea545258a3
# GAP TSN: 180154 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930305
# ----
# bBBWAx - Dendroica castanea(Bay-breasted Warbler)
# https://www.sciencebase.gov/catalog/item/58fa456de4b0b7ea54524cd8
# GAP TSN: 178912 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950036
# ----
# bBTNWx - Dendroica virens(Black-throated Green Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4719e4b0b7ea54524dd0
# GAP TSN: 178898 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950061
# ----
# bLAGOx - Carduelis lawrencei(Lawrence's Goldfinch)
# https://www.sciencebase.gov/catalog/item/58fa4e51e4b0b7ea54525101
# GAP TSN: 179232 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179257
# ----
# mSRBVb - Myodes gapperi brevicaudus(Black Hills Red-backed Vole)
# https://www.sciencebase.gov/catalog/item/58fa7ba2e4b0b7ea54525b6f
# GAP TSN: 180294 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:970612
# ----
# bWIWAx - Wilsonia pusilla(Wilson's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5d50e4b0b7ea545255e3
# GAP TSN: 178973 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950080
# ----
# mWEPMx - Perognathus alticolus(White-eared Pocket Mouse)
# https://www.sciencebase.gov/catalog/item/58fa7f50e4b0b7ea54525bed
# GAP TSN: 180255 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:900644
# ----
# bBOSPx - Aimophila botterii(Botteri's Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa468be4b0b7ea54524d83
# GAP TSN: 179390 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997734
# ----
# bLEGOx - Carduelis psaltria(Lesser Goldfinch)
# https://www.sciencebase.gov/catalog/item/58fa4eeae4b0b7ea54525140
# GAP TSN: 179234 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179254
# ----
# bGRWAx - Dendroica graciae(Grace's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4c9de4b0b7ea54525057
# GAP TSN: 178909 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950056
# ----
# bMGWAx - Oporornis tolmiei(Macgillivray's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa507be4b0b7ea545251d3
# GAP TSN: 178940 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950023
# ----
# bABTOx - Pipilo aberti(Abert's Towhee)
# https://www.sciencebase.gov/catalog/item/58fa4438e4b0b7ea54524c22
# GAP TSN: 179307 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997739
# ----
# bSAGSb - Amphispiza belli belli(Bell's Sage Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa5667e4b0b7ea545253bb
# GAP TSN: 179402 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997724
# ----
# mTGSQx - Spermophilus townsendii(Townsend's Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7d48e4b0b7ea54525ba5
# GAP TSN: 180161 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930323
# ----
# bLOWAx - Seiurus motacilla(Louisiana Waterthrush)
# https://www.sciencebase.gov/catalog/item/58fa4f95e4b0b7ea54525184
# GAP TSN: 178935 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950009
# ----
# mSPOGx - Geomys streckeri(Strecker's Pocket Gopher)
# https://www.sciencebase.gov/catalog/item/58fa7b5de4b0b7ea54525b66
# GAP TSN: 900166 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:900261
# ----
# bCANTx - Pipilo fuscus(Canyon Towhee)
# https://www.sciencebase.gov/catalog/item/58fa47efe4b0b7ea54524e3a
# GAP TSN: 179293 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997737
# ----
# bMCLOx - Calcarius mccownii(Mccown's Longspur)
# https://www.sciencebase.gov/catalog/item/58fa5048e4b0b7ea545251c0
# GAP TSN: 179525 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997873
# ----
# bVIWAx - Vermivora virginiae(Virginia's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5b63e4b0b7ea5452555a
# GAP TSN: 178864 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950019
# ----
# bCAFIx - Carpodacus cassinii(Cassin's Finch)
# https://www.sciencebase.gov/catalog/item/58fa47b7e4b0b7ea54524e1f
# GAP TSN: 179190 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997804
# ----
# bTOWAx - Dendroica townsendi(Townsend's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5a2de4b0b7ea545254f4
# GAP TSN: 178897 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950058
# ----
# mRGSQx - Spermophilus richardsonii(Richardson's Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa76c1e4b0b7ea54525abb
# GAP TSN: 180157 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930322
# ----
# bLUWAx - Vermivora luciae(Lucy's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4fb2e4b0b7ea54525190
# GAP TSN: 178866 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950017
# ----
# mMGSQx - Spermophilus canus(Merriam's Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6ee1e4b0b7ea54525986
# GAP TSN: 552499 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930317
# ----
# mEAPIx - Pipistrellus subflavus(Eastern Pipistrelle)
# https://www.sciencebase.gov/catalog/item/58fa66d2e4b0b7ea5452583d
# GAP TSN: 180025 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:948895
# ----
# aOSSAx - Batrachoseps wrightorum(Oregon Slender Salamander)
# https://www.sciencebase.gov/catalog/item/58fa41ade4b0b7ea54524a98
# GAP TSN: 573579 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173712
# ----
# mFGSQx - Spermophilus franklinii(Franklin's Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6837e4b0b7ea54525879
# GAP TSN: 180153 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930309
# ----
# bBOGUx - Larus philadelphia(Bonaparte's Gull)
# https://www.sciencebase.gov/catalog/item/58fa467ee4b0b7ea54524d7b
# GAP TSN: 176839 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824040
# ----
# rBHLIx - Phrynosoma blainvillii(Blainville's Horned Lizard)
# https://www.sciencebase.gov/catalog/item/58fe0b7ae4b00749282945a3
# GAP TSN: 208819 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:173939
# ----
# bKIWAx - Dendroica kirtlandii(Kirtland's Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4e47e4b0b7ea545250fd
# GAP TSN: 178917 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950030
# ----
# bEVGRx - Coccothraustes vespertinus(Evening Grosbeak)
# https://www.sciencebase.gov/catalog/item/58fa4a8de4b0b7ea54524f72
# GAP TSN: 179173 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179175
# ----
# mBGSQx - Spermophilus beldingi(Belding's Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa61e8e4b0b7ea5452574f
# GAP TSN: 180149 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930315
# ----
# bCASPx - Aimophila cassinii(Cassin's Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa4819e4b0b7ea54524e4e
# GAP TSN: 179393 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997732
# ----
# aGCTOx - Ollotis nebulifer(Gulf Coast Toad)
# https://www.sciencebase.gov/catalog/item/58fa4051e4b0b7ea5452498a
# GAP TSN: 775988 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:773583
# ----
# bFSSPx - Aimophila quinquestriata(Five-striped Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa4af6e4b0b7ea54524fa0
# GAP TSN: 554030 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179408
# ----
# bYRWAx - Dendroica coronata(Yellow-rumped Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5f17e4b0b7ea5452567d
# GAP TSN: 178891 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950046
# ----
# bCALTx - Pipilo crissalis(California Towhee)
# https://www.sciencebase.gov/catalog/item/58fa47e0e4b0b7ea54524e33
# GAP TSN: 202307 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997738
# ----
# bCSWAx - Dendroica pensylvanica(Chestnut-sided Warbler)
# https://www.sciencebase.gov/catalog/item/58fa49aee4b0b7ea54524f09
# GAP TSN: 178911 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950040
# ----
# bROYTx - Thalasseus maximus(Royal Tern)
# https://www.sciencebase.gov/catalog/item/58fa5594e4b0b7ea54525379
# GAP TSN: 176922 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824142
# ----
# bTRPAx - Parula pitiayumi(Tropical Parula)
# https://www.sciencebase.gov/catalog/item/58fa5a73e4b0b7ea5452550f
# GAP TSN: 178869 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950034
# ----
# mSGSQx - Spermophilus spilosoma(Spotted Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7951e4b0b7ea54525b1b
# GAP TSN: 180159 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930312
# ----
# bSAGSc - Amphispiza belli clementeae(San Clemente Sage Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa5675e4b0b7ea545253c0
# GAP TSN: 179402 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997724
# ----
# bBTYWx - Dendroica nigrescens(Black-throated Gray Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4731e4b0b7ea54524ddb
# GAP TSN: 178896 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950057
# ----
# bPISIx - Carduelis pinus(Pine Siskin)
# https://www.sciencebase.gov/catalog/item/58fa5349e4b0b7ea545252c1
# GAP TSN: 179233 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179246
# ----
# mIGSQx - Spermophilus brunneus(Idaho Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6b17e4b0b7ea545258f0
# GAP TSN: 180150 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930316
# ----
# bLAGUx - Leucophaeus atricilla(Laughing Gull)
# https://www.sciencebase.gov/catalog/item/58fa4e5ae4b0b7ea54525105
# GAP TSN: 176837 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824079
# ----
# mNAPOx - Erethizon dorsatum(North American Porcupine)
# https://www.sciencebase.gov/catalog/item/58fa70a4e4b0b7ea545259cb
# GAP TSN: 180393 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:825295
# ----
# mCASQx - Spermophilus beecheyi(California Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa633ce4b0b7ea5452579a
# GAP TSN: 180148 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930301
# ----
# mDFWOs - Neotoma fuscipes riparia(San Joaquin Valley Wood Rat)
# https://www.sciencebase.gov/catalog/item/58fa65c8e4b0b7ea5452580d
# GAP TSN: 633407 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:180373
# ----
# bAMGOx - Carduelis tristis(American Goldfinch)
# https://www.sciencebase.gov/catalog/item/58fa4481e4b0b7ea54524c4b
# GAP TSN: 179236 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179249
# ----
# bHOFIx - Carpodacus mexicanus(House Finch)
# https://www.sciencebase.gov/catalog/item/58fa4d83e4b0b7ea545250b1
# GAP TSN: 179191 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997805
# ----
# bPRAWx - Dendroica discolor(Prairie Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5389e4b0b7ea545252d6
# GAP TSN: 178918 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950052
# ----
# bPAWAx - Dendroica palmarum(Palm Warbler)
# https://www.sciencebase.gov/catalog/item/58fa52cce4b0b7ea5452529a
# GAP TSN: 178921 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950043
# ----
# bHOWAx - Wilsonia citrina(Hooded Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4dd0e4b0b7ea545250cb
# GAP TSN: 178972 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950029
# ----
# bMAWAx - Dendroica magnolia(Magnolia Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5034e4b0b7ea545251b8
# GAP TSN: 178886 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950035
# ----
# bATSPx - Spizella arborea(American Tree Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa44ece4b0b7ea54524c8e
# GAP TSN: 179432 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997961
# ----
# bSOTEx - Onychoprion fuscatus(Sooty Tern)
# https://www.sciencebase.gov/catalog/item/58fa584be4b0b7ea54525452
# GAP TSN: 176894 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:824105
# ----
# bCOREx - Carduelis flammea(Common Redpoll)
# https://www.sciencebase.gov/catalog/item/58fa4985e4b0b7ea54524ef6
# GAP TSN: 179230 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:179241
# ----
# mGMGSx - Spermophilus lateralis(Golden-mantled Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6943e4b0b7ea545258a6
# GAP TSN: 180154 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930305
# ----
# mMESQx - Spermophilus mexicanus(Mexican Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa6e5ae4b0b7ea54525974
# GAP TSN: 180155 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930307
# ----
# mUGSQx - Spermophilus armatus(Uinta Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7e31e4b0b7ea54525bc6
# GAP TSN: 180147 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930314
# ----
# mROSQx - Spermophilus variegatus(Rock Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7712e4b0b7ea54525ac7
# GAP TSN: 180163 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930302
# ----
# mCOSQx - Spermophilus columbianus(Columbian Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa64b3e4b0b7ea545257da
# GAP TSN: 180151 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930318
# ----
# mWASQx - Spermophilus washingtoni(Washington Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7ef9e4b0b7ea54525be1
# GAP TSN: 180164 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930325
# ----
# mWRBVx - Myodes californicus(Western Red-backed Vole)
# https://www.sciencebase.gov/catalog/item/58fa80a3e4b0b7ea54525c17
# GAP TSN: 180295 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:970610
# ----
# bGCWAx - Dendroica chrysoparia(Golden-cheeked Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4b75e4b0b7ea54524fd5
# GAP TSN: 178901 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950060
# ----
# mRTGSx - Spermophilus tereticaudus(Round-tailed Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7773e4b0b7ea54525ad6
# GAP TSN: 180160 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930313
# ----
# bRWSPx - Aimophila carpalis(Rufous-winged Sparrow)
# https://www.sciencebase.gov/catalog/item/58fa563ce4b0b7ea545253ad
# GAP TSN: 179375 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:997731
# ----
# mWYSQx - Spermophilus elegans(Wyoming Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fe0980e4b007492829451d
# GAP TSN: 180152 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930319
# ----
# bYTWAx - Dendroica dominica(Yellow-throated Warbler)
# https://www.sciencebase.gov/catalog/item/58fa5f36e4b0b7ea5452568c
# GAP TSN: 178905 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950049
# ----
# mTLGSx - Spermophilus tridecemlineatus(Thirteen-lined Ground Squirrel)
# https://www.sciencebase.gov/catalog/item/58fa7d71e4b0b7ea54525bab
# GAP TSN: 180162 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:930308
# ----
# bNOWAx - Seiurus noveboracensis(Northern Waterthrush)
# https://www.sciencebase.gov/catalog/item/58fa51c9e4b0b7ea54525246
# GAP TSN: 178931 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950010
# ----
# mSAMBx - Rusa unicolor(Sambar)
# https://www.sciencebase.gov/catalog/item/58fa77dbe4b0b7ea54525ae5
# GAP TSN: 625051 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:898215
# ----
# rSOPTx - Chrysemys dorsalis(Southern Painted Turtle)
# https://www.sciencebase.gov/catalog/item/58fe27e3e4b0f87f0854af11
# GAP TSN: 208623 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:208622
# ----
# mYFPGx - Cratogeomys castanops(Yellow-faced Pocket Gopher)
# https://www.sciencebase.gov/catalog/item/58fe09dde4b007492829452d
# GAP TSN: 180220 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:900158
# ----
# bCERWx - Dendroica cerulea(Cerulean Warbler)
# https://www.sciencebase.gov/catalog/item/58fa4872e4b0b7ea54524e78
# GAP TSN: 178903 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:950032
# ----
# rCNIGx - Hypsiglena ochrorhyncha(Coast Nightsnake)
# https://www.sciencebase.gov/catalog/item/58fe0f1ae4b007492829462f
# GAP TSN: 209311 (usage: invalid)
# Accepted ITIS TSN/Link: http://services.itis.gov/?q=tsn:683068
# ----
