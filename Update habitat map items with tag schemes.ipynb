# %% [markdown]
# This notebook updates all of the GAP species habitat map items in ScienceBase to call out, explicitly, the scientific name and common name used by GAP for these items. The problem in the previous code that generated these items was that there was no way in code to determine which name was which. In this process, I eliminated the "United States" place name tag for now. We will be running another process once these items are registered to feed back SGCN states as a specific type of "place" identifier for faceted searching.

# %%
import requests,configparser,pysb,os,time
from IPython.display import display
import pandas as pd

# %%
sb = pysb.SbSession()
username = input("Username: ")
sb.loginc(str(username))
# Out:
# Username: sbristol@usgs.gov
# ········

# %%
# Get API keys and any other config details from a file that is external to the code.
config = configparser.RawConfigParser()
config.read_file(open(r'../config/stuff.py'))

# %%
# Build base URL with API key using input from the external config.
def getBaseURL():
    gc2APIKey = config.get('apiKeys','apiKey_GC2_BCB').replace('"','')
    apiBaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?key="+gc2APIKey
    return apiBaseURL

# %%
gapInventory = pd.read_table("ScienceBaseCSV_20170417NT.csv", sep=",")

# %%
habitatMapCollectionID = "527d0a83e4b0850ea0518326"

collectionIDs = sb.get_child_ids(habitatMapCollectionID)

for item in collectionIDs:
    thisItem = sb.get_item(item)
    thisItemTags = {}
    thisItemTags["id"] = item
    for identifier in thisItem["identifiers"]:
        if identifier["type"] == "GAP_SpeciesCode":
            gapCode = identifier["key"]
            scientificName = {}
            scientificName["type"] = "Theme"
            scientificName["scheme"] = "https://www.sciencebase.gov/vocab/bis/tir/scientificname"
            scientificName["name"] = gapInventory.loc[gapInventory['GAP_code'] == gapCode, 'scientific_name'].iloc[0]

            commonName = {}
            commonName["type"] = "Theme"
            commonName["scheme"] = "https://www.sciencebase.gov/vocab/bis/tir/commonname"
            commonName["name"] = gapInventory.loc[gapInventory['GAP_code'] == gapCode, 'common_name'].iloc[0]

            thisItemTags["tags"] = [scientificName,commonName]
            
            break
    
    display (sb.update_item(thisItemTags))
    time.sleep(1)
# Out:
# {'body': 'This dataset represents a species habitat distribution model for Ovenbird.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Ovenbird (Seiurus aurocapilla) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F70G3HHH\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'email': 'ntarr@usgs.gov',
#    'firstName': 'Nathan',
#    'lastName': 'Tarr',
#    'middleName': 'M',
#    'name': 'Nathan M Tarr',
#    'oldPartyId': 66146,
#    'organization': {'displayText': 'Core Science Analytics, Synthesis and Libraries'},
#    'primaryLocation': {'building': 'Bldg Record',
#     'buildingCode': 'AVD',
#     'mailAddress': {},
#     'name': 'CN=Nathan M Tarr,OU=GAP Contractors,OU=Users,OU=BoiseID-B,OU=WR,DC=gs,DC=doi,DC=net - Primary Location',
#     'officePhone': '9195137280',
#     'streetAddress': {'city': 'Raleigh',
#      'line1': 'David Clark Labs, NC State Univ',
#      'state': 'NC',
#      'zip': '27695-7617'}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa527ce4b0b7ea54525280',
#  'identifiers': [{'key': 'bOVENx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F70G3HHH\n         ',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '726205',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '103515',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABPBX10010',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa527ce4b0b7ea54525280'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T18:42:04Z',
#   'lastUpdated': '2017-05-15T22:42:17Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa527ce4b0b7ea54525280'}},
#  'summary': "This dataset represents a species habitat distribution model for Ovenbird. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Seiurus aurocapilla',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Ovenbird',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Ovenbird (Seiurus aurocapilla) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'title': 'Source Data: Elevation',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e111e4b0a658d79395d9'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103515'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=726205'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:726205'}]}
# {'body': 'This dataset represents a species habitat distribution model for Pacific Loon.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Pacific Loon (Gavia pacifica) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F7GH9G8X\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'email': 'mrubino@usgs.gov',
#    'firstName': 'Matthew',
#    'lastName': 'Rubino',
#    'middleName': 'J',
#    'name': 'Matthew J Rubino',
#    'oldPartyId': 66147,
#    'organization': {'displayText': 'Core Science Analytics, Synthesis and Libraries'},
#    'primaryLocation': {'building': 'Bldg Record',
#     'buildingCode': 'AVD',
#     'mailAddress': {},
#     'name': 'CN=Matthew J Rubino,OU=GAP Contractors,OU=Users,OU=BoiseID-B,OU=WR,DC=gs,DC=doi,DC=net - Primary Location',
#     'officePhone': '9195137280',
#     'streetAddress': {'city': 'Raleigh',
#      'line1': 'David Clark Labs, NC State Univ',
#      'state': 'NC',
#      'zip': '27695-7617'}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa52b2e4b0b7ea54525293',
#  'identifiers': [{'key': 'bPALOx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F7GH9G8X\n         ',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '174475',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '100814',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABNBA01050',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa52b2e4b0b7ea54525293'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T18:42:58Z',
#   'lastUpdated': '2017-05-15T22:42:17Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa52b2e4b0b7ea54525293'}},
#  'summary': "This dataset represents a species habitat distribution model for Pacific Loon. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Gavia pacifica',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Pacific Loon',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Pacific Loon (Gavia pacifica) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100814'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=174475'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:174475'}]}
# {'body': 'This dataset represents a species habitat distribution model for Pied-billed Grebe.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Pied-billed Grebe (Podilymbus podiceps) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F73B5XGB\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'email': 'ntarr@usgs.gov',
#    'firstName': 'Nathan',
#    'lastName': 'Tarr',
#    'middleName': 'M',
#    'name': 'Nathan M Tarr',
#    'oldPartyId': 66146,
#    'organization': {'displayText': 'Core Science Analytics, Synthesis and Libraries'},
#    'primaryLocation': {'building': 'Bldg Record',
#     'buildingCode': 'AVD',
#     'mailAddress': {},
#     'name': 'CN=Nathan M Tarr,OU=GAP Contractors,OU=Users,OU=BoiseID-B,OU=WR,DC=gs,DC=doi,DC=net - Primary Location',
#     'officePhone': '9195137280',
#     'streetAddress': {'city': 'Raleigh',
#      'line1': 'David Clark Labs, NC State Univ',
#      'state': 'NC',
#      'zip': '27695-7617'}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa52d8e4b0b7ea5452529e',
#  'identifiers': [{'key': 'bPBGRx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F73B5XGB\n         ',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '174505',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '100209',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABNCA02010',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa52d8e4b0b7ea5452529e'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T18:43:36Z',
#   'lastUpdated': '2017-05-15T22:42:17Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa52d8e4b0b7ea5452529e'}},
#  'summary': "This dataset represents a species habitat distribution model for Pied-billed Grebe. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Podilymbus podiceps',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Pied-billed Grebe',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Pied-billed Grebe (Podilymbus podiceps) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: Hydrography',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540eb44e4b0a658d7939624'},
#   {'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'title': 'Source Data: Elevation',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e111e4b0a658d79395d9'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.100209'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=174505'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:174505'}]}
