# %% [markdown]
# This notebook uses a local dump that I assembled in a MongoDB database of the GAP range data for processing. I found some errant codes in the data that did not align with the code values that I found in the gapproduction package. The notebook checks the data and reports on any cases where there is a code value that does not have a corresponding code definition/term in the dictionary.

# %%
from pymongo import MongoClient
from IPython.display import display

# %%
mdbClient = MongoClient()
bis = mdbClient["bis"]
gapRangeDataCache = bis["gapRangeData"]

# %% [markdown]
# This is the dictionary of codes and values for range data that I pulled from https://github.com/nmtarr/GAPProduction/blob/master/gapproduction/dictionaries.py.
#
# Eventually, we need to move this content to an appropriate master vocabulary source as part of the Biogeographic Information System. I did that with a set of vocabularies [here](https://www.sciencebase.gov/vocab/category/59f60211e4b09d26336e76eb) and tried to use the ScienceBase Vocab API to drive the code that assembles a cache of the range data for a given species in CSV. Unfortunately, the Vocab app seems to be having some issues with how it builds its index, so I could not use that source directly. We may need to find another tech base to move all the BIS vocabularies into if we cannot get those issues resolved.

# %%
RangeCodesDict = {"Presence": {1: "Known/extant", 2: "Possibly present", 3: "Potential for presence", 
                               4: "Extirpated/historical presence", 
                               5: "Extirpated purposely (applies to introduced species only)",
                                6: "Occurs on indicated island chain", 7: "Unknown"},
                "Origin": {1: "Native", 2: "Introduced", 3: "Either introducted or native", 
                           4: "Reintroduced", 5: "Either introduced or reintroduced",
                           6: "Vagrant", 7: "Unknown"},
                "Reproduction": {1: "Breeding", 2: "Nonbreeding", 
                                 3: "Both breeding and nonbreeding", 7: "Unknown"},
                 "Season": {1: "Year-round", 2: "Migratory", 3: "Winter", 4: "Summer", 
                            5: "Passage migrant or wanderer", 6: "Seasonal permanence uncertain", 
                            7: "Unknown", 8: "Vagrant"}}

# %% [markdown]
# These 4 code blocks check the full set of range data across all 4 taxa groups to see if there are any errant code numbers. You can see the records returned for just a couple of species that need to be examined to see if we made a mistake in assigning codes or need to add new definitions.

# %%
for rangeRecord in gapRangeDataCache.find({"intGapPres":{"$nin":list(RangeCodesDict["Presence"].keys())}}):
    display (rangeRecord)
# Out:
# ServerSelectionTimeoutErrorTraceback (most recent call last)
# <ipython-input-4-5b57aafa2452> in <module>()
# ----> 1 for rangeRecord in gapRangeDataCache.find({"intGapPres":{"$nin":list(RangeCodesDict["Presence"].keys())}}):
#       2     display (rangeRecord)
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\cursor.pyc in next(self)
#    1112             raise StopIteration
#    1113         _db = self.__collection.database
# -> 1114         if len(self.__data) or self._refresh():
#    1115             if self.__manipulate:
#    1116                 return _db._fix_outgoing(self.__data.popleft(),
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\cursor.pyc in _refresh(self)
#    1034                                        self.__batch_size,
#    1035                                        self.__read_concern,
# -> 1036                                        self.__collation))
#    1037             if not self.__id:
#    1038                 self.__killed = True
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\cursor.pyc in __send_message(self, operation)
#     871             try:
#     872                 response = client._send_message_with_response(operation,
# --> 873                                                               **kwargs)
#     874                 self.__address = response.address
#     875                 if self.__exhaust:
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\mongo_client.pyc in _send_message_with_response(self, operation, read_preference, exhaust, address)
#     886         else:
#     887             selector = read_preference or writable_server_selector
# --> 888             server = topology.select_server(selector)
#     889
#     890         # A _Query's slaveOk bit is already set for queries with non-primary
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\topology.pyc in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# C:\Users\nmtarr\AppData\Local\Continuum\Anaconda2\lib\site-packages\pymongo\topology.pyc in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 10061] No connection could be made because the target machine actively refused it

# %%
for rangeRecord in gapRangeDataCache.find({"intGapOrigin":{"$nin":list(RangeCodesDict["Origin"].keys())}}):
    display (rangeRecord)

# %%
for rangeRecord in gapRangeDataCache.find({"intGapRepro":{"$nin":list(RangeCodesDict["Reproduction"].keys())}}):
    display (rangeRecord)
# Out:
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6600a3339a20cad65f6a7'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 160201020703,
#  'strUC': 'aGRFRx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f661853339a20cad6c513e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170102130703,
#  'strUC': 'aRSNEx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f661853339a20cad6c513f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170102130704,
#  'strUC': 'aRSNEx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f661853339a20cad6c51a3'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170601080201,
#  'strUC': 'aRSNEx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f661853339a20cad6c51a4'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170601080202,
#  'strUC': 'aRSNEx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0518'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 10900020701,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0519'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040301,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051a'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040302,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040304,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040401,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040402,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040403,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f051f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301040404,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0520'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050303,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0521'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050304,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0522'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050305,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0523'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050306,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0524'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050307,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0525'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050401,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0526'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050402,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0527'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050403,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0528'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050404,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0529'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050405,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052a'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050503,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050505,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050506,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20301050507,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20401050801,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f052f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20401050802,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0530'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20401050803,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0531'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010101,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0532'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010102,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0533'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010103,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0534'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010104,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0596'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010105,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0597'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010401,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0598'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20402010402,
#  'strUC': 'mBTJAx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f66e3c3339a20cad9f0599'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 20
),
#  'intGapOrigin': 2,
#  'intGapPres': 2,
#  'intGapRepro': 7,
#  'intGapSeas': 1,
#  'strHUC12RNG': 180500020901,
#  'strUC': 'mEBSQx'}
# {'Origin': 'Introduced',
#  'Presence': 'Possibly present',
#  'Reproduction': 'Unknown',
#  'Season': 'Year-round',
#  '_id': ObjectId('59f670c63339a20cadaa48dd'),
#  'intGapOrigin': 2,
#  'intGapPres': 2,
# ...
#  'strHUC12RNG': 170701030302,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d4b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030303,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d4c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030304,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d4d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030305,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d4e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030306,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d4f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030408,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d50'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030501,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d51'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030502,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d52'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030503,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d53'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030504,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d54'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030505,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d55'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030506,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d56'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030507,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d57'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030609,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d58'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030701,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d59'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030702,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5a'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030703,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030704,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030705,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030706,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030801,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d5f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030802,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d60'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030803,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d61'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030905,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d62'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030906,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d63'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701030907,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d64'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031002,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d65'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031003,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d66'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031101,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d67'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031102,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d68'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031103,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d69'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031104,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6a'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031201,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031202,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031203,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031204,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031205,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d6f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031206,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d70'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031207,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d71'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031301,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d72'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031302,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d73'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031303,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d74'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031304,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d75'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031305,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d76'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701031306,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d77'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040201,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d78'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040202,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d79'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040203,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7a'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040204,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7b'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040307,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7c'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040405,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7d'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040406,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7e'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040407,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d7f'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040408,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d80'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040501,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d81'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040502,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d82'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701040503,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6f1dc3339a20cad859d83'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 170701060301,
#  'strUC': 'bNOBOx'}
# {'Origin': 'Introduced',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f6fbe53339a20cadb09913'),
#  'intGapOrigin': 2,
#  'intGapPres': 1,
#  'intGapRepro': 7,
#  'intGapSeas': 7,
#  'strHUC12RNG': 51201010601,
#  'strUC': 'bROPIx'}

# %%
for rangeRecord in gapRangeDataCache.find({"intGapSeas":{"$nin":list(RangeCodesDict["Season"].keys())}}):
    display (rangeRecord)
# Out:
# {'Origin': 'Native',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f68b8a3339a20cad26f13b'),
#  'intGapOrigin': 1,
#  'intGapPres': 1,
#  'intGapRepro': 0,
#  'intGapSeas': 0,
#  'strHUC12RNG': 20600020101,
#  'strUC': 'bCOEIx'}
# {'Origin': 'Native',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Unknown',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f68b8a3339a20cad26f13d'),
#  'intGapOrigin': 1,
#  'intGapPres': 1,
#  'intGapRepro': 0,
#  'intGapSeas': 0,
#  'strHUC12RNG': 20600020103,
#  'strUC': 'bCOEIx'}
# {'Origin': 'Native',
#  'Presence': 'Known/extant',
#  'Reproduction': 'Nonbreeding',
#  'Season': 'Unknown',
#  '_id': ObjectId('59f68d9c3339a20cad302b6f'),
#  'intGapOrigin': 1,
#  'intGapPres': 1,
#  'intGapRepro': 2,
#  'intGapSeas': 0,
#  'strHUC12RNG': 30202040404,
#  'strUC': 'bCOTEx'}
