# %%
import pysb,time
from IPython.display import display

# %%
sb = pysb.SbSession()
username = input("Username: ")
sb.loginc(str(username))
# Out:
# Username: sbristol@usgs.gov
# ········

# %%
habitatMapCollectionID = "527d0a83e4b0850ea0518326"

collectionIDs = sb.get_child_ids(habitatMapCollectionID)

for item in collectionIDs:
    thisItem = sb.get_item(item)
    thisItemUpdate = {}
    thisItemUpdate["id"] = item

    thisItemNewIdentifiers = []
    for identifier in thisItem["identifiers"]:
        if identifier["type"] == "DOI":
            thisID = {}
            thisID["type"] = identifier["type"]
            thisID["scheme"] = identifier["scheme"]
            thisID["key"] = identifier["key"].strip()
        else:
            thisID = identifier
        thisItemNewIdentifiers.append(thisID.copy())
        thisItemUpdate["identifiers"] = thisItemNewIdentifiers

    sb.update_item(thisItemUpdate)
    display (thisItemUpdate)
    time.sleep(0.5)
# Out:
# {'body': 'This dataset represents a species habitat distribution model for Caribou.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Caribou (Rangifer tarandus) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F7J101JH\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'email': 'mrubino@usgs.gov',
#    'firstName': 'Matthew',
#    'lastName': 'Rubino',
#    'middleName': 'J',
#    'name': 'Matthew J Rubino',
#    'oldPartyId': 66147,
#    'organization': {'displayText': 'Core Science Analytics, Synthesis and Libraries'},
#    'primaryLocation': {'building': 'Bldg Record',
#     'buildingCode': 'AVD',
#     'mailAddress': {},
#     'name': 'CN=Matthew J Rubino,OU=GAP Contractors,OU=Users,OU=BoiseID-B,OU=WR,DC=gs,DC=doi,DC=net - Primary Location',
#     'officePhone': '9195137280',
#     'streetAddress': {'city': 'Raleigh',
#      'line1': 'David Clark Labs, NC State Univ',
#      'state': 'NC',
#      'zip': '27695-7617'}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2016', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa6318e4b0b7ea54525794',
#  'identifiers': [{'key': 'mCARIx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F7J101JH',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '180701',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '103369',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'AMALC04010',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa6318e4b0b7ea54525794'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T19:52:56Z',
#   'lastUpdated': '2017-05-22T13:33:18Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa6318e4b0b7ea54525794'}},
#  'summary': "This dataset represents a species habitat distribution model for Caribou. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Rangifer tarandus',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Caribou',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Caribou (Rangifer tarandus) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103369'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180701'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:180701'}]}
# {'body': 'This dataset represents a species habitat distribution model for California Sealion.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, California Sealion (Zalophus californianus) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F7D798T7\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'name': 'Thomas Laxon',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2014', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa632be4b0b7ea54525797',
#  'identifiers': [{'key': 'mCASEx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F7D798T7',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '180621',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '103040',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'AMAJC04010',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa632be4b0b7ea54525797'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T19:53:15Z',
#   'lastUpdated': '2017-05-22T13:33:19Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa632be4b0b7ea54525797'}},
#  'summary': "This dataset represents a species habitat distribution model for California Sealion. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Zalophus californianus',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'California Sealion',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'California Sealion (Zalophus californianus) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'title': 'Source Data: Hydrography',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540eb44e4b0a658d7939624'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.103040'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=180621'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:180621'}]}
# {'body': 'This dataset represents a species habitat distribution model for Wilson\'s Plover.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': "U.S. Geological Survey - Gap Analysis Program, 2017, Wilson's Plover (Charadrius wilsonia) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F7P55KVP\n         .",
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'email': 'jlonneker@usgs.gov',
#    'firstName': 'Jeffrey',
#    'lastName': 'Lonneker',
#    'middleName': 'J',
#    'name': 'Jeffrey J Lonneker',
#    'oldPartyId': 62787,
#    'organization': {'displayText': 'Core Science Analytics, Synthesis and Libraries'},
#    'primaryLocation': {'building': 'Plaza West',
#     'buildingCode': 'WIF',
#     'mailAddress': {},
#     'name': 'CN=Jeffrey J Lonneker,OU=GS VPN Accounts,OU=Users,OU=DenverCO-I ServiceDesk,OU=DenverCO-M,OU=CR,DC=gs,DC=doi,DC=net - Primary Location',
#     'officePhone': '2088853534',
#     'streetAddress': {'city': 'Moscow',
#      'line1': '530 Ashbury St',
#      'state': 'ID',
#      'zip': '83843'}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa5cf5e4b0b7ea545255cb',
#  'identifiers': [{'key': 'bWIPLx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F7P55KVP',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '176517',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '104251',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABNNB03040',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa5cf5e4b0b7ea545255cb'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T19:26:45Z',
#   'lastUpdated': '2017-05-22T13:33:19Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa5cf5e4b0b7ea545255cb'}},
#  'summary': "This dataset represents a species habitat distribution model for Wilson's Plover. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Charadrius wilsonia',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': "Wilson's Plover",
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': "Wilson's Plover (Charadrius wilsonia) Habitat Map",
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.104251'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=176517'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:176517'}]}
# {'body': 'This dataset represents a species habitat distribution model for Black-tailed Gnatcatcher.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Black-tailed Gnatcatcher (Polioptila melanura) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F78G8J11\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'name': 'Robert Adair',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa46fee4b0b7ea54524dc4',
#  'identifiers': [{'key': 'bBTGNx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F78G8J11',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '179857',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '101192',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABPBJ08030',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa46fee4b0b7ea54524dc4'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T17:53:02Z',
#   'lastUpdated': '2017-05-22T13:33:20Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa46fee4b0b7ea54524dc4'}},
#  'summary': "This dataset represents a species habitat distribution model for Black-tailed Gnatcatcher. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Polioptila melanura',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Black-tailed Gnatcatcher',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Black-tailed Gnatcatcher (Polioptila melanura) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.101192'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=179857'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:179857'}]}
# {'body': 'This dataset represents a species habitat distribution model for Great Cormorant.  These habitat maps are created by applying a <a href="https://www.sciencebase.gov/catalog/item/527d0a83e4b0850ea0518326">deductive habitat model</a> to remotely-sensed data layers within a species\' range.',
#  'citation': 'U.S. Geological Survey - Gap Analysis Program, 2017, Great Cormorant (Phalacrocorax carbo) Habitat Map, U.S. Geological Survey data release, https://doi:10.5066/F7513WJK\n         .',
#  'contacts': [{'contactType': 'person',
#    'email': 'amckerrow@usgs.gov',
#    'name': 'Dr. Alexa McKerrow',
#    'organization': {'displayText': 'U.S. Geological Survey/Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Raleigh',
#      'country': 'United States',
#      'line1': 'North Carolina State University, Campus Box 7617',
#      'state': 'NC',
#      'zip': '27695-7617'},
#     'officePhone': '571-218-5474',
#     'streetAddress': {}},
#    'type': 'Point of Contact'},
#   {'name': 'U.S. Geological Survey - Gap Analysis Program',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Originator'},
#   {'contactType': 'person',
#    'email': 'jpmagee@usgs.gov',
#    'jobTitle': 'Technical Information Specialist',
#    'name': 'Julie Prior-Magee',
#    'organization': {'displayText': 'U.S. Geological Survey - Core Science Analytics, Synthesis, and Libraries'},
#    'primaryLocation': {'mailAddress': {'city': 'Lakewood',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, West 6th Avenue & Kipling, Bldg. 810, MS 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '575-557-1566',
#     'streetAddress': {}},
#    'type': 'Metadata Contact'},
#   {'name': 'U.S. Geological Survey',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Publisher'},
#   {'contactType': 'person',
#    'email': 'sciencebase@usgs.gov',
#    'name': 'ScienceBase Data Release Team',
#    'organization': {'displayText': 'U.S. Geological Survey - ScienceBase'},
#    'primaryLocation': {'mailAddress': {'city': 'Denver',
#      'country': 'United States',
#      'line1': 'Denver Federal Center, Building 810, Mail Stop 302',
#      'state': 'CO',
#      'zip': '80225'},
#     'officePhone': '888-275-8747',
#     'streetAddress': {}},
#    'type': 'Distributor'},
#   {'contactType': 'person',
#    'name': 'Robert Adair',
#    'organization': {},
#    'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#    'type': 'Modeler'}],
#  'dates': [{'dateString': '2017',
#    'label': 'Publication Date',
#    'type': 'Publication'},
#   {'dateString': '2008', 'label': 'Start Date', 'type': 'Start'},
#   {'dateString': '2013', 'label': 'End Date', 'type': 'End'}],
#  'distributionLinks': [],
#  'hasChildren': False,
#  'id': '58fa4bf8e4b0b7ea54525011',
#  'identifiers': [{'key': 'bGRCOx',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'GAP_SpeciesCode'},
#   {'key': 'doi:10.5066/F7513WJK',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'DOI'},
#   {'key': 'IP-082267',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'IPDS'},
#   {'key': '174715',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'ITIS_TSN'},
#   {'key': '102054',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'EGTID'},
#   {'key': 'ABNFD01010',
#    'scheme': 'https://www.sciencebase.gov/vocab/category/item/identifier',
#    'type': 'NatureServeElementCode'}],
#  'link': {'rel': 'self',
#   'url': 'https://www.sciencebase.gov/catalog/item/58fa4bf8e4b0b7ea54525011'},
#  'locked': False,
#  'parentId': '527d0a83e4b0850ea0518326',
#  'permissions': {'read': {'acl': [],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'},
#   'write': {'acl': ['ROLE:ScienceBase_DataAdmin',
#     'USER:amckerrow@usgs.gov',
#     'USER:cbelyea@ncsu.edu',
#     'USER:dwieferich@usgs.gov',
#     'USER:jpmagee@usgs.gov',
#     'USER:lschueck@usgs.gov',
#     'USER:nmtarr@ncsu.edu',
#     'USER:ntarr@usgs.gov',
#     'USER:saulenbach@usgs.gov',
#     'USER:sgwilliams@usgs.gov'],
#    'inherited': True,
#    'inheritsFromId': '527d0a83e4b0850ea0518326'}},
#  'provenance': {'annotation': 'Creation of item from csv file using pysb',
#   'createdBy': 'dwieferich@usgs.gov',
#   'dateCreated': '2017-04-21T18:14:16Z',
#   'lastUpdated': '2017-05-22T13:33:20Z',
#   'lastUpdatedBy': 'sbristol@usgs.gov'},
#  'purpose': "GAP distribution models represent the areas where species are predicted to occur based on habitat associations. The distribution models represent the spatial arrangement of environments suitable for occupation by a species. In other words, a species distribution is created using a deductive model to predict areas suitable for occupation within a species range. To represent these suitable environments for this species' habitat distribution model, we used the land cover and other ancillary datasets listed here in this metadata. Details on the habitat affinities and the parameters used to model are provided in the species report in the attached files section of this record.These models can be used to assess the habitat availability across the range of the species and in combination with other data to assess the conservation status or threats to the habitat for the species.",
#  'relatedItems': {'link': {'rel': 'related',
#    'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=58fa4bf8e4b0b7ea54525011'}},
#  'summary': "This dataset represents a species habitat distribution model for Great Cormorant. These habitat maps are created by applying a deductive habitat model to remotely-sensed data layers within a species' range.",
#  'tags': [{'name': 'Phalacrocorax carbo',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/scientificname',
#    'type': 'Theme'},
#   {'name': 'Great Cormorant',
#    'scheme': 'https://www.sciencebase.gov/vocab/bis/tir/commonname',
#    'type': 'Theme'}],
#  'title': 'Great Cormorant (Phalacrocorax carbo) Habitat Map',
#  'webLinks': [{'hidden': False,
#    'title': 'Source Data: National GAP Land Cover V1',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540e2d7e4b0a658d79395db'},
#   {'hidden': False,
#    'title': 'Source Data: Hydrography',
#    'type': 'Related data',
#    'typeLabel': 'Source Dataset',
#    'uri': 'https://www.sciencebase.gov/catalog/item/5540eb44e4b0a658d7939624'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'NatureServe Explorer Species Profile Page',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://www.natureserve.org/explorer/servlet/NatureServe?searchSpeciesUid=ELEMENT_GLOBAL.2.102054'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS Report',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'https://www.itis.gov/servlet/SingleRpt/SingleRpt?search_topic=TSN&search_value=174715'},
#   {'hidden': False,
#    'rel': 'related',
#    'title': 'ITIS SOLR Service',
#    'type': 'webLink',
#    'typeLabel': 'Web Link',
#    'uri': 'http://services.itis.gov/?q=tsn:174715'}]}
