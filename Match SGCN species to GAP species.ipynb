# %% [markdown]
# N. Tarr 8/2/2018
#
# Python 2.7
#
# Description: Matches SGCN species to GAP species when possible.  Tries to match on different things starting with ITIS TSN, tries to then match unmatched species on scientific and then common name. Inserts matches in to SGCN-GAP_matches collection in the bis database.  Prints non-matched SGCN species at the end.
#
# Notes: Running this code requires access to the gapproduction package, which requires arcpy and connection to the NCSU GAP databases.
#
# It is necessary to have access to info from NCSU GAP databases on gap species name-ITIS crosswalk info.  Here, it is accessed with a csv file.  Each GAP species is linked with an ITIS TSN.  However, some GAP species are not recognized by ITIS or direct matches will require extensive review of literature.  GAP species may be linked to a "parent" TSN (e.g. for the Genus) in such cases.  These cases created some one-to-many matches (one SGCN to many GAP) that were sometimes resolved by matching on TSN AND scientific name.

# %%
import pandas as pd
pd.set_option('display.width', 1000)
import sys
sys.path.append("T:/BCB/")
import BISdbConfig
import pprint
execfile("T:/Scripts/AppendPaths27.py")
execfile("T:/Scripts/AppendGAPAnalysis.py")
import gapproduction as gp
import pymongo

# %% [markdown]
# Functions and variables for connecting to bis database

# %%
host="54.91.95.139"
port=27017
username=BISdbConfig.user
password=BISdbConfig.password

def _connect_mongodb(host, port, username, password, db):
    """ A util for making a connection to mongo """

    if username and password:
        mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, db)
        conn = pymongo.MongoClient(mongo_uri)
    else:
        conn = pymongo.MongoClient(host, port)
        
    return conn[db]

def get_collection_cursor(db, collection, host, port, username, password, query={}):
    """ Read from Mongo """

    # Connect to MongoDB
    db = _connect_mongodb(host=host, port=port, username=username, password=password, db=db)

    # Make a query to the specific DB and Collection
    cursor = db[collection].find(query)
    
    return cursor

# %% [markdown]
# ## Create a dictionary to hold SGCN - GAP matches

# %%
matches = {}
non_matches = {}

# %% [markdown]
# ## Read in GAP Scientific Names, TSN codes, and species codes

# %%
# Read in csv of gap species, species codes, and TSN codes and notes
gapSpecies = pd.read_csv("T:/SALCC/GAPspecies2.csv")
gapSpecies.drop(["scientific_name", "common_name"],inplace=True, axis=1)
gapSpecies.drop(columns=["Unnamed: 0"],inplace=True, axis=1)
gapSpecies['intITIScode'].fillna(0, inplace=True)
gapSpecies['intITIScode'] = [int(i) for i in gapSpecies['intITIScode']]

# Print first 5 records
gapSpecies.head()
# Out:
#     strUC                     strSciName                                strComName  intITIScode  intGapITISmatch                                    strGapITISmatch                                       memTaxaNotes
# 0  rLWWHx             Aspidoscelis gypsi                     Little White Whiptail       174021              6.0  ITIS does not recognize this species concept. ...  Aspidoscelis gypsi (Little White Whiptail) is ...
# 1  rDENIx         Hypsiglena chlorophaea                         Desert Nightsnake       174233              6.0  ITIS does not recognize this species concept. ...  Hypsiglena chlorophaea (Desert Nightsnake) is ...
# 2  rCHNIx                Hypsiglena jani                     Chihuahuan Nightsnake       174233              6.0  ITIS does not recognize this species concept. ...  Hypsiglena jani (Chihuahuan Nightsnake) is rec...
# 3  rWNLIx              Xantusia wigginsi                     Wiggins' Night Lizard       174092              6.0  ITIS does not recognize this species concept. ...  Based on mitochondrial and nuclear DNA data, S...
# 4  mPYRAc  Brachylagus idahoensis pop. 2  Pygmy Rabbit (Columbia Basin Population)       552521              5.0  ITIS does not recognize this sub-population co...  NatureServe recognizes a distinct subpopulatio...

# %% [markdown]
# ## Read in SGCN Scientific Names and TSN codes
# Define the search query for filtering out unwanted records from the bis database.  No need for aquatic or invertebrates or species only listed in AK.

# %%
# Get a list of state names for the query.  We will want to exclude non-lower 48 state species.
lower48s = list(set(gp.dictionaries.stateDict_To_Abbr.keys()) - set(["Northern Mariana Islands", "Alaska", "Puerto Rico", 
                                                           "American Samoa", "Guam", "Virgin Islands", "Hawaii"]))

# Get a list of taxanomic groups GAP modeled (terrestrial)
terrSpecies = ["Birds", "Reptiles", "Amphibians", "Mammals"]

query = {"State Summary.2015.State List": { "$in": lower48s }, 
         "State Summary.2005.State List": { "$in": lower48s },
         "Taxonomic Group": {"$in": terrSpecies}
         }

# %% [markdown]
# ## Attempt to match with GAP

# %% [markdown]
# ### TSN matches
# Process each document in the collection. for each document/record, check to see if the SGCN TSN is associated with a GAP species.  If it is, collect that record and match.  Note that there are some one-to-many matches on TSN (one SGCN TSN to many GAP species; sometimes due to subspecies).  In those cases, attempt to find a match on TSN and scientific name.

# %%
# Get a cursor for the SGCN Synthesis collection from bis
SGCNcursor = get_collection_cursor(db='bis', collection='SGCN Synthesis', query=query, host=host, port=port, 
                                   username=username, password=password)

# Loop through SGCN's and collect matches on TSN
for x in SGCNcursor:
    tsn = int(x['Taxonomic Authority ID'][-6:])
    sciname = x['Taxonomy'][-1]['name']
    # If the tsn occurs in the GAP taxonomy, then proceed, otherwise collect as a non-match
    if int(tsn) in set(gapSpecies.intITIScode):
        GAPtsnDF = gapSpecies[gapSpecies['intITIScode'] == tsn]
        # One-to-one TSN: If there's one occurrence of the tsn in GAP taxonomy, then collect as a match
        if len(GAPtsnDF) == 1:
            spInfo = {}
            spInfo["SGCN_id"] = sciname
            spInfo["SGCN-ITIS_TSN"] = tsn
            spInfo["SGCN_common_name"] = x['Common Name']
            spInfo["GAP-ITIS_TSN"] = tsn
            spInfo["GAP_scientific_name"] = GAPtsnDF["strSciName"].unique()[0]
            spInfo["GAP_common_name"] = gp.gapdb.NameCommon(GAPtsnDF["strUC"].unique()[0])
            spInfo["GAP_species_code"] = GAPtsnDF["strUC"].unique()[0]
            spInfo["GAP-ITIS_match_notes"] = GAPtsnDF["strGapITISmatch"].unique()[0]
            spInfo["GAP_taxa_notes"] = GAPtsnDF["memTaxaNotes"].unique()[0]
            spInfo["SGCN-GAP_match_basis"] = "TSN" 
            spInfo["SGCN-GAP_match_notes"] = "exact match"
            matches[sciname] = spInfo
        # One-to-many TSN: If the tsn occurs twice in GAP taxonomy, match on scientific name and tsn, provided
        # that the sgcn scientific name occurs in GAP taxonomy.
        elif len(GAPtsnDF) != 1 and sciname in GAPtsnDF['strSciName'].unique():
            DF1 = GAPtsnDF[GAPtsnDF['strSciName'] == sciname]
            spInfo = {}
            spInfo["SGCN_id"] = sciname
            spInfo["SGCN-ITIS_TSN"] = tsn
            spInfo["SGCN_common_name"] = x['Common Name']
            spInfo["GAP-ITIS_TSN"] = tsn
            spInfo["GAP_scientific_name"] = DF1["strSciName"].unique()[0]
            spInfo["GAP_common_name"] = gp.gapdb.NameCommon(DF1["strUC"].unique()[0])
            spInfo["GAP_species_code"] = DF1["strUC"].unique()[0]
            spInfo["GAP-ITIS_match_notes"] = DF1["strGapITISmatch"].unique()[0]
            spInfo["GAP_taxa_notes"] = DF1["memTaxaNotes"].unique()[0]
            spInfo["SGCN-GAP_match_basis"] = "TSN and scientific name" 
            spInfo["SGCN-GAP_match_notes"] = "exact match"
            matches[sciname] = spInfo
        # If the tsn occurs in the GAP taxonomy but not with the sgcn scientific name, count as a mismatch.  These cases
        # don't seem to occur.
        else:
            spInfo = {}
            spInfo["SGCN_scientific_name"] = sciname
            spInfo["SGCN-ITIS_TSN"] = tsn
            spInfo["SGCN_common_name"] = x['Common Name']
            non_matches[sciname] = spInfo
    # Collect as a mismatch because the tsn isn't in the GAP taxonomy.
    else:
        spInfo = {}
        spInfo["SGCN_scientific_name"] = sciname
        spInfo["SGCN-ITIS_TSN"] = tsn
        spInfo["SGCN_common_name"] = x['Common Name']
        non_matches[sciname] = spInfo

# %% [markdown]
# Show the number of records in each dictionary

# %%
print("SGCN Synthesis documents: " + str(len(list(get_collection_cursor(db='bis', collection='SGCN Synthesis', 
                                                                        query=query, host=host, port=port,
                                                                        username=username, password=password)))))
print("GAP species: 1719")
print("Matches: " + str(len(matches.keys())))
print("Non-matches: " + str(len(non_matches.keys())))
# Out:
# SGCN Synthesis documents: 1425
# GAP species: 1719
# Matches: 1062
# Non-matches: 363

# %% [markdown]
# ### Match on scientific names
# See if any non-matches can be matched on scientific name.

# %%
# Loop through non-matches and collect matches on scientific name.
for x in non_matches.keys():   
    if x in set(gapSpecies.strSciName) and x not in matches.keys():
        print(x)
        GAPsciDF = gapSpecies[gapSpecies['strSciName'] == x]
        spInfo = {}
        spInfo["SGCN_id"] = x
        spInfo["SGCN-ITIS_TSN"] = non_matches[x]["SGCN-ITIS_TSN"]
        spInfo["SGCN_common_name"] = non_matches[x]['SGCN_common_name']
        spInfo["GAP-ITIS_TSN"] = GAPsciDF["intITIScode"].unique()[0]
        spInfo["GAP_scientific_name"] = GAPsciDF["strSciName"].unique()[0]
        spInfo["GAP_common_name"] = gp.gapdb.NameCommon(GAPsciDF["strUC"].unique()[0])
        spInfo["GAP_species_code"] = GAPsciDF["strUC"].unique()[0]
        spInfo["GAP-ITIS_match_notes"] = GAPsciDF["strGapITISmatch"].unique()[0]
        spInfo["GAP_taxa_notes"] = GAPsciDF["memTaxaNotes"].unique()[0]
        spInfo["SGCN-GAP_match_basis"] = "scientific name" 
        spInfo["SGCN-GAP_match_notes"] = "exact match"
        matches[x] = spInfo
        #pprint.pprint(spInfo)
        del non_matches[x]
# Out:
# Onychoprion fuscatus
# Onychoprion anaethetus
# Chroicocephalus philadelphia
# Leucophaeus atricilla
# Grus canadensis
# Tringa semipalmata
# Kinosternon subrubrum
# Hydrocoloeus minutus
# Thalasseus maximus
# Leucophaeus pipixcan
# Cratogeomys castanops

# %% [markdown]
# Show the number of records in each dictionary

# %%
print("SGCN Synthesis documents: " + str(len(list(get_collection_cursor(db='bis', collection='SGCN Synthesis', 
                                                                        query=query, host=host, port=port,
                                                                        username=username, password=password)))))
print("GAP species: 1719")
print("Matches: " + str(len(matches.keys())))
print("Non-matches: " + str(len(non_matches.keys())))
# Out:
# SGCN Synthesis documents: 1425
# GAP species: 1719
# Matches: 1073
# Non-matches: 352

# %% [markdown]
# ### Match on common names
# See if any non-matches can be matched on common name.

# %%
# Loop through non-matches and collect matches on common name.
for x in non_matches.keys():   
    comname = non_matches[x]['SGCN_common_name']
    if comname in set(gapSpecies.strComName) and x not in matches.keys():
        print("\n\t\t" + comname)
        GAPcomDF = gapSpecies[gapSpecies['strComName'] == comname]
        spInfo = {}
        spInfo["SGCN_id"] = x
        spInfo["SGCN-ITIS_TSN"] = non_matches[x]["SGCN-ITIS_TSN"]
        spInfo["SGCN_common_name"] = comname
        spInfo["GAP-ITIS_TSN"] = GAPcomDF["intITIScode"].unique()[0]
        spInfo["GAP_scientific_name"] = GAPcomDF["strSciName"].unique()[0]
        spInfo["GAP_common_name"] = gp.gapdb.NameCommon(GAPcomDF["strUC"].unique()[0])
        spInfo["GAP_species_code"] = GAPcomDF["strUC"].unique()[0]
        spInfo["GAP-ITIS_match_notes"] = GAPcomDF["strGapITISmatch"].unique()[0]
        spInfo["GAP_taxa_notes"] = GAPcomDF["memTaxaNotes"].unique()[0]
        spInfo["SGCN-GAP_match_basis"] = "common name" 
        spInfo["SGCN-GAP_match_notes"] = "exact match"
        matches[x] = spInfo
        pprint.pprint(spInfo)
        del non_matches[x]
# Out:
# 		Blackburnian Warbler
# {'GAP-ITIS_TSN': 178904,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Blackburnian Warbler',
#  'GAP_scientific_name': 'Dendroica fusca',
#  'GAP_species_code': 'bBLBWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950037,
#  'SGCN_common_name': u'Blackburnian Warbler',
#  'SGCN_id': u'Setophaga fusca'}
#
# 		Ornate Box Turtle
# {'GAP-ITIS_TSN': 173778,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Ornate Box Turtle',
#  'GAP_scientific_name': 'Terrapene ornata',
#  'GAP_species_code': 'rOBTUx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208604,
#  'SGCN_common_name': u'Ornate Box Turtle',
#  'SGCN_id': u'Terrapene ornata ornata'}
#
# 		Orange-crowned Warbler
# {'GAP-ITIS_TSN': 178856,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Orange-crowned Warbler',
#  'GAP_scientific_name': 'Vermivora celata',
#  'GAP_species_code': 'bOCWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950015,
#  'SGCN_common_name': u'Orange-crowned Warbler',
#  'SGCN_id': u'Leiothlypis celata'}
#
# 		American Tree Sparrow
# {'GAP-ITIS_TSN': 179432,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'American Tree Sparrow',
#  'GAP_scientific_name': 'Spizella arborea',
#  'GAP_species_code': 'bATSPx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997961,
#  'SGCN_common_name': u'American Tree Sparrow',
#  'SGCN_id': u'Spizelloides arborea'}
#
# 		Yellow-rumped Warbler
# {'GAP-ITIS_TSN': 178891,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Yellow-rumped Warbler',
#  'GAP_scientific_name': 'Dendroica coronata',
#  'GAP_species_code': 'bYRWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950046,
#  'SGCN_common_name': u'Yellow-rumped Warbler',
#  'SGCN_id': u'Setophaga coronata'}
#
# 		Roseate Tern
# {'GAP-ITIS_TSN': 176891,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Roseate Tern',
#  'GAP_scientific_name': 'Sterna dougallii',
#  'GAP_species_code': 'bROSTx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 176892,
#  'SGCN_common_name': u'Roseate Tern',
#  'SGCN_id': u'Sterna dougallii dougallii'}
#
# 		Cerulean Warbler
# {'GAP-ITIS_TSN': 178903,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Cerulean Warbler',
#  'GAP_scientific_name': 'Dendroica cerulea',
#  'GAP_species_code': 'bCERWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950032,
#  'SGCN_common_name': u'Cerulean Warbler',
#  'SGCN_id': u'Setophaga cerulea'}
#
# 		Northern Waterthrush
# {'GAP-ITIS_TSN': 178931,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Northern Waterthrush',
#  'GAP_scientific_name': 'Seiurus noveboracensis',
#  'GAP_species_code': 'bNOWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950010,
#  'SGCN_common_name': u'Northern Waterthrush',
#  'SGCN_id': u'Parkesia noveboracensis'}
#
# 		Flammulated Owl
# {'GAP-ITIS_TSN': 177878,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Flammulated Owl',
#  'GAP_scientific_name': 'Otus flammeolus',
#  'GAP_species_code': 'bFLOWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 63247,
#  'SGCN_common_name': u'Flammulated Owl',
#  'SGCN_id': u'Psiloscops flammeolus'}
#
# 		Pine Warbler
# {'GAP-ITIS_TSN': 178914,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Pine Warbler',
#  'GAP_scientific_name': 'Dendroica pinus',
#  'GAP_species_code': 'bPIWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950045,
#  'SGCN_common_name': u'Pine Warbler',
#  'SGCN_id': u'Setophaga pinus'}
#
# 		Boreal Chickadee
# {'GAP-ITIS_TSN': 726112,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Boreal Chickadee',
#  'GAP_scientific_name': 'Poecile hudsonica',
#  'GAP_species_code': 'bBOCHx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 554386,
#  'SGCN_common_name': u'Boreal Chickadee',
#  'SGCN_id': u'Poecile hudsonicus'}
#
# 		Elk
# {'GAP-ITIS_TSN': 180695,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Elk',
#  'GAP_scientific_name': 'Cervus elaphus',
#  'GAP_species_code': 'mELK1x',
#  'GAP_taxa_notes': 'Cervus elaphus subspecies of C. e. nannodes and  C. e. roosevelti (Tule and Roosevelt elk, respectively) were included because of their definitive ranges and conservation concern from a historical perspective.\r\nITIS does not recognize C. e. roosevelti.\r\nSGW 29 September 2017',
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 898519,
#  'SGCN_common_name': u'Elk',
#  'SGCN_id': u'Cervus elaphus canadensis'}
#
# 		North American Porcupine
# {'GAP-ITIS_TSN': 180393,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'North American Porcupine',
#  'GAP_scientific_name': 'Erethizon dorsata',
#  'GAP_species_code': 'mNAPOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 825295,
#  'SGCN_common_name': u'North American Porcupine',
#  'SGCN_id': u'Erethizon dorsatus'}
#
# 		Lucy's Warbler
# {'GAP-ITIS_TSN': 178866,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Lucy's Warbler",
#  'GAP_scientific_name': 'Vermivora luciae',
#  'GAP_species_code': 'bLUWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950017,
#  'SGCN_common_name': u"Lucy's Warbler",
#  'SGCN_id': u'Leiothlypis luciae'}
#
# 		Bachman's Sparrow
# {'GAP-ITIS_TSN': 179386,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Bachman's Sparrow",
#  'GAP_scientific_name': 'Aimophila aestivalis',
#  'GAP_species_code': 'bBACSx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997733,
#  'SGCN_common_name': u"Bachman's Sparrow",
#  'SGCN_id': u'Peucaea aestivalis'}
#
# 		Hooded Warbler
# {'GAP-ITIS_TSN': 178972,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Hooded Warbler',
#  'GAP_scientific_name': 'Wilsonia citrina',
#  'GAP_species_code': 'bHOWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950029,
#  'SGCN_common_name': u'Hooded Warbler',
#  'SGCN_id': u'Setophaga citrina'}
#
# 		White-winged Scoter
# {'GAP-ITIS_TSN': 175163,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'White-winged Scoter',
#  'GAP_scientific_name': 'Melanitta fusca',
#  'GAP_species_code': 'bWWSCx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 175165,
#  'SGCN_common_name': u'White-winged Scoter',
#  'SGCN_id': u'Melanitta fusca deglandi'}
#
# 		Botteri's Sparrow
# {'GAP-ITIS_TSN': 179390,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Botteri's Sparrow",
#  'GAP_scientific_name': 'Aimophila botterii',
#  'GAP_species_code': 'bBOSPx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997734,
#  'SGCN_common_name': u"Botteri's Sparrow",
#  'SGCN_id': u'Peucaea botterii'}
#
# 		Sonoran Desert Toad
# {'GAP-ITIS_TSN': 775976,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Sonoran Desert Toad',
#  'GAP_scientific_name': 'Ollotis alvaria',
#  'GAP_species_code': 'aSNTOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 773562,
#  'SGCN_common_name': u'Sonoran Desert Toad',
#  'SGCN_id': u'Incilius alvarius'}
#
# 		Snowy Plover
# {'GAP-ITIS_TSN': 824030,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Snowy Plover',
#  'GAP_scientific_name': 'Charadrius nivosus',
#  'GAP_species_code': 'bSNPLx',
#  'GAP_taxa_notes': 'Updated GAP scientific name to match ITIS and NatureServe which recognize Western hemisphere Snowy Plovers (Charadrius nivosus) as distinct from Old World Snowy Plovers (Charadrius alexandrinus).\r\nSGW 29 September 2017',
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 176510,
#  'SGCN_common_name': u'Snowy Plover',
#  'SGCN_id': u'Charadrius alexandrinus'}
#
# 		Cassin's Finch
# {'GAP-ITIS_TSN': 179190,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Cassin's Finch",
#  'GAP_scientific_name': 'Carpodacus cassinii',
#  'GAP_species_code': 'bCAFIx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997804,
#  'SGCN_common_name': u"Cassin's Finch",
#  'SGCN_id': u'Haemorhous cassinii'}
#
# 		Northern Parula
# {'GAP-ITIS_TSN': 178868,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Northern Parula',
#  'GAP_scientific_name': 'Parula americana',
#  'GAP_species_code': 'bNOPAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950033,
#  'SGCN_common_name': u'Northern Parula',
#  'SGCN_id': u'Setophaga americana'}
#
# 		White-eared Pocket Mouse
# {'GAP-ITIS_TSN': 180255,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'White-eared Pocket Mouse',
#  'GAP_scientific_name': 'Perognathus alticolus',
#  'GAP_species_code': 'mWEPMx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 900885,
#  'SGCN_common_name': u'White-eared Pocket Mouse',
#  'SGCN_id': u'Perognathus alticolus alticolus'}
#
# 		Yellow-throated Warbler
# {'GAP-ITIS_TSN': 178905,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Yellow-throated Warbler',
#  'GAP_scientific_name': 'Dendroica dominica',
#  'GAP_species_code': 'bYTWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950049,
#  'SGCN_common_name': u'Yellow-throated Warbler',
#  'SGCN_id': u'Setophaga dominica'}
#
# 		Fisher
# {'GAP-ITIS_TSN': 180560,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Fisher',
#  'GAP_scientific_name': 'Martes pennanti',
#  'GAP_species_code': 'mFISHx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 727128,
#  'SGCN_common_name': u'Fisher',
#  'SGCN_id': u'Martes pennanti pacifica'}
#
# 		Sonoran Mud Turtle
# {'GAP-ITIS_TSN': 173768,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Sonoran Mud Turtle',
#  'GAP_scientific_name': 'Kinosternon sonoriense',
#  'GAP_species_code': 'rSOMTx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208586,
#  'SGCN_common_name': u'Sonoran Mud Turtle',
#  'SGCN_id': u'Kinosternon sonoriense sonoriense'}
#
# 		Mourning Warbler
# {'GAP-ITIS_TSN': 178939,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Mourning Warbler',
#  'GAP_scientific_name': 'Oporornis philadelphia',
#  'GAP_species_code': 'bMOWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950024,
#  'SGCN_common_name': u'Mourning Warbler',
#  'SGCN_id': u'Geothlypis philadelphia'}
#
# 		Black-throated Blue Warbler
# {'GAP-ITIS_TSN': 178888,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Black-throated Blue Warbler',
#  'GAP_scientific_name': 'Dendroica caerulescens',
#  'GAP_species_code': 'bBTBWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950042,
#  'SGCN_common_name': u'Black-throated Blue Warbler',
#  'SGCN_id': u'Setophaga caerulescens'}
#
# 		Yellow Rail
# {'GAP-ITIS_TSN': 176259,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Yellow Rail',
#  'GAP_scientific_name': 'Coturnicops noveboracensis',
#  'GAP_species_code': 'bYERAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 176260,
#  'SGCN_common_name': u'Yellow Rail',
#  'SGCN_id': u'Coturnicops noveboracensis noveboracensis'}
#
# 		Coal Skink
# {'GAP-ITIS_TSN': 208882,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Coal Skink',
#  'GAP_scientific_name': 'Plestiodon anthracinus',
#  'GAP_species_code': 'rCOSKx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 173962,
#  'SGCN_common_name': u'Coal Skink',
#  'SGCN_id': u'Eumeces anthracinus'}
#
# 		American Kestrel
# {'GAP-ITIS_TSN': 175622,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'American Kestrel',
#  'GAP_scientific_name': 'Falco sparverius',
#  'GAP_species_code': 'bAMKEx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 175624,
#  'SGCN_common_name': u'American Kestrel',
#  'SGCN_id': u'Falco sparverius paulus'}
#
# 		Cassin's Sparrow
# {'GAP-ITIS_TSN': 179393,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Cassin's Sparrow",
#  'GAP_scientific_name': 'Aimophila cassinii',
#  'GAP_species_code': 'bCASPx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997732,
#  'SGCN_common_name': u"Cassin's Sparrow",
#  'SGCN_id': u'Peucaea cassinii'}
#
# 		Western Pipistrelle
# {'GAP-ITIS_TSN': 180024,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Western Pipistrelle',
#  'GAP_scientific_name': 'Pipistrellus hesperus',
#  'GAP_species_code': 'mWEPIx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 947298,
#  'SGCN_common_name': u'Western Pipistrelle',
#  'SGCN_id': u'Parastrellus hesperus'}
#
# 		Southern Painted Turtle
# {'GAP-ITIS_TSN': 208623,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Southern Painted Turtle',
#  'GAP_scientific_name': 'Chrysemys dorsalis',
#  'GAP_species_code': 'rSOPTx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208622,
#  'SGCN_common_name': u'Southern Painted Turtle',
#  'SGCN_id': u'Chrysemys picta dorsalis'}
#
# 		Georgia Blind Salamander
# {'GAP-ITIS_TSN': 173717,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Georgia Blind Salamander',
#  'GAP_scientific_name': 'Haideotriton wallacei',
#  'GAP_species_code': 'aGBSAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 775913,
#  'SGCN_common_name': u'Georgia Blind Salamander',
#  'SGCN_id': u'Eurycea wallacei'}
#
# 		Cape May Warbler
# {'GAP-ITIS_TSN': 178887,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Cape May Warbler',
#  'GAP_scientific_name': 'Dendroica tigrina',
#  'GAP_species_code': 'bCMWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950031,
#  'SGCN_common_name': u'Cape May Warbler',
#  'SGCN_id': u'Setophaga tigrina'}
#
# 		Tennessee Warbler
# {'GAP-ITIS_TSN': 178855,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Tennessee Warbler',
#  'GAP_scientific_name': 'Vermivora peregrina',
#  'GAP_species_code': 'bTEWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950014,
#  'SGCN_common_name': u'Tennessee Warbler',
#  'SGCN_id': u'Leiothlypis peregrina'}
#
# 		Five-striped Sparrow
# {'GAP-ITIS_TSN': 554030,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Five-striped Sparrow',
#  'GAP_scientific_name': 'Aimophila quinquestriata',
#  'GAP_species_code': 'bFSSPx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 179408,
#  'SGCN_common_name': u'Five-striped Sparrow',
#  'SGCN_id': u'Amphispiza quinquestriata'}
#
# 		Blue-winged Warbler
# {'GAP-ITIS_TSN': 178853,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Blue-winged Warbler',
#  'GAP_scientific_name': 'Vermivora pinus',
#  'GAP_species_code': 'bBWWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950011,
#  'SGCN_common_name': u'Blue-winged Warbler',
#  'SGCN_id': u'Vermivora cyanoptera'}
#
# 		Chestnut-sided Warbler
# {'GAP-ITIS_TSN': 178911,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Chestnut-sided Warbler',
#  'GAP_scientific_name': 'Dendroica pensylvanica',
#  'GAP_species_code': 'bCSWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950040,
#  'SGCN_common_name': u'Chestnut-sided Warbler',
#  'SGCN_id': u'Setophaga pensylvanica'}
#
# 		Blackpoll Warbler
# {'GAP-ITIS_TSN': 178913,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Blackpoll Warbler',
#  'GAP_scientific_name': 'Dendroica striata',
#  'GAP_species_code': 'bBLPWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950041,
#  'SGCN_common_name': u'Blackpoll Warbler',
#  'SGCN_id': u'Setophaga striata'}
#
# 		Black-throated Green Warbler
# {'GAP-ITIS_TSN': 178898,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Black-throated Green Warbler',
#  'GAP_scientific_name': 'Dendroica virens',
#  'GAP_species_code': 'bBTNWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950061,
#  'SGCN_common_name': u'Black-throated Green Warbler',
#  'SGCN_id': u'Setophaga virens'}
#
# 		Sonoran Mud Turtle
# {'GAP-ITIS_TSN': 173768,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Sonoran Mud Turtle',
#  'GAP_scientific_name': 'Kinosternon sonoriense',
#  'GAP_species_code': 'rSOMTx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208585,
#  'SGCN_common_name': u'Sonoran Mud Turtle',
#  'SGCN_id': u'Kinosternon sonoriense longifemorale'}
#
# 		Pine Siskin
# {'GAP-ITIS_TSN': 179233,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Pine Siskin',
#  'GAP_scientific_name': 'Carduelis pinus',
#  'GAP_species_code': 'bPISIx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 179246,
#  'SGCN_common_name': u'Pine Siskin',
#  'SGCN_id': u'Spinus pinus'}
#
# 		Golden-cheeked Warbler
# {'GAP-ITIS_TSN': 178901,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Golden-cheeked Warbler',
#  'GAP_scientific_name': 'Dendroica chrysoparia',
#  'GAP_species_code': 'bGCWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950060,
#  'SGCN_common_name': u'Golden-cheeked Warbler',
#  'SGCN_id': u'Setophaga chrysoparia'}
#
# 		Abert's Towhee
# {'GAP-ITIS_TSN': 179307,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Abert's Towhee",
#  'GAP_scientific_name': 'Pipilo aberti',
#  'GAP_species_code': 'bABTOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997739,
#  'SGCN_common_name': u"Abert's Towhee",
#  'SGCN_id': u'Melozone aberti'}
#
# 		Canada Warbler
# {'GAP-ITIS_TSN': 178977,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Canada Warbler',
#  'GAP_scientific_name': 'Wilsonia canadensis',
#  'GAP_species_code': 'bCAWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950079,
#  'SGCN_common_name': u'Canada Warbler',
#  'SGCN_id': u'Cardellina canadensis'}
#
# 		False Map Turtle
# {'GAP-ITIS_TSN': 173800,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'False Map Turtle',
#  'GAP_scientific_name': 'Graptemys pseudogeographica',
#  'GAP_species_code': 'rFMTUx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208637,
#  'SGCN_common_name': u'False Map Turtle',
#  'SGCN_id': u'Graptemys pseudogeographica pseudogeographica'}
#
# 		Southeastern Pocket Gopher
# {'GAP-ITIS_TSN': 180218,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Southeastern Pocket Gopher',
#  'GAP_scientific_name': 'Geomys pinetis',
#  'GAP_species_code': 'mSEGOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 900262,
#  'SGCN_common_name': u'Southeastern Pocket Gopher',
#  'SGCN_id': u'Geomys pinetis pinetis'}
#
# 		Chisel-toothed Kangaroo Rat
# {'GAP-ITIS_TSN': 180242,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Chisel-toothed Kangaroo Rat',
#  'GAP_scientific_name': 'Dipodomys microps',
#  'GAP_species_code': 'mCTKRx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 900694,
#  'SGCN_common_name': u'Chisel-toothed Kangaroo Rat',
#  'SGCN_id': u'Dipodomys microps celsus'}
#
# 		Louisiana Waterthrush
# {'GAP-ITIS_TSN': 178935,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Louisiana Waterthrush',
#  'GAP_scientific_name': 'Seiurus motacilla',
#  'GAP_species_code': 'bLOWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950009,
#  'SGCN_common_name': u'Louisiana Waterthrush',
#  'SGCN_id': u'Parkesia motacilla'}
#
# 		Rainbow Snake
# {'GAP-ITIS_TSN': 174166,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Rainbow Snake',
#  'GAP_scientific_name': 'Farancia erytrogramma',
#  'GAP_species_code': 'rRASNx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 174167,
#  'SGCN_common_name': u'Rainbow Snake',
#  'SGCN_id': u'Farancia erytrogramma erytrogramma'}
#
# 		Ouachita Map Turtle
# {'GAP-ITIS_TSN': 173799,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Ouachita Map Turtle',
#  'GAP_scientific_name': 'Graptemys ouachitensis',
#  'GAP_species_code': 'rOMTUx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 914050,
#  'SGCN_common_name': u'Ouachita Map Turtle',
#  'SGCN_id': u'Graptemys ouachitensis ouachitensis'}
#
# 		Eastern Box Turtle
# {'GAP-ITIS_TSN': 173776,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Eastern Box Turtle',
#  'GAP_scientific_name': 'Terrapene carolina',
#  'GAP_species_code': 'rEBTUx',
#  'GAP_taxa_notes': "ITIS does not recognize Terrapene carolina bauri (Florida Box Turtle) subspecies. However, NatureServe recognizes the subpecies. We chose to map it due to it's conservation status and distinct range.\r\nSGW 29 September 2017",
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 173777,
#  'SGCN_common_name': u'Eastern Box Turtle',
#  'SGCN_id': u'Terrapene carolina carolina'}
#
# 		Northern Goshawk
# {'GAP-ITIS_TSN': 175300,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Northern Goshawk',
#  'GAP_scientific_name': 'Accipiter gentilis',
#  'GAP_species_code': 'bNOGOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 175301,
#  'SGCN_common_name': u'Northern Goshawk',
#  'SGCN_id': u'Accipiter gentilis atricapillus'}
#
# 		Tropical Parula
# {'GAP-ITIS_TSN': 178869,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Tropical Parula',
#  'GAP_scientific_name': 'Parula pitiayumi',
#  'GAP_species_code': 'bTRPAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950034,
#  'SGCN_common_name': u'Tropical Parula',
#  'SGCN_id': u'Setophaga pitiayumi'}
#
# 		Virginia's Warbler
# {'GAP-ITIS_TSN': 178864,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Virginia's Warbler",
#  'GAP_scientific_name': 'Vermivora virginiae',
#  'GAP_species_code': 'bVIWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950019,
#  'SGCN_common_name': u"Virginia's Warbler",
#  'SGCN_id': u'Leiothlypis virginiae'}
#
# 		Kirtland's Warbler
# {'GAP-ITIS_TSN': 178917,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Kirtland's Warbler",
#  'GAP_scientific_name': 'Dendroica kirtlandii',
#  'GAP_species_code': 'bKIWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950030,
#  'SGCN_common_name': u"Kirtland's Warbler",
#  'SGCN_id': u'Setophaga kirtlandii'}
#
# 		Evening Grosbeak
# {'GAP-ITIS_TSN': 179173,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Evening Grosbeak',
#  'GAP_scientific_name': 'Coccothraustes vespertinus',
#  'GAP_species_code': 'bEVGRx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 179175,
#  'SGCN_common_name': u'Evening Grosbeak',
#  'SGCN_id': u'Hesperiphona vespertina'}
#
# 		Oregon Slender Salamander
# {'GAP-ITIS_TSN': 573579,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Oregon Slender Salamander',
#  'GAP_scientific_name': 'Batrachoseps wrightorum',
#  'GAP_species_code': 'aOSSAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 173712,
#  'SGCN_common_name': u'Oregon Slender Salamander',
#  'SGCN_id': u'Batrachoseps wrighti'}
#
# 		Plains Pocket Mouse
# {'GAP-ITIS_TSN': 180261,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Plains Pocket Mouse',
#  'GAP_scientific_name': 'Perognathus flavescens',
#  'GAP_species_code': 'mPPMOx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 900899,
#  'SGCN_common_name': u'Plains Pocket Mouse',
#  'SGCN_id': u'Perognathus flavescens perniger'}
#
# 		Grace's Warbler
# {'GAP-ITIS_TSN': 178909,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u"Grace's Warbler",
#  'GAP_scientific_name': 'Dendroica graciae',
#  'GAP_species_code': 'bGRWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950056,
#  'SGCN_common_name': u"Grace's Warbler",
#  'SGCN_id': u'Setophaga graciae'}
#
# 		Prairie Skink
# {'GAP-ITIS_TSN': 208900,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Prairie Skink',
#  'GAP_scientific_name': 'Plestiodon septentrionalis',
#  'GAP_species_code': 'rPRSKx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 173969,
#  'SGCN_common_name': u'Prairie Skink',
#  'SGCN_id': u'Eumeces septentrionalis'}
#
# 		Mudpuppy
# {'GAP-ITIS_TSN': 173630,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Mudpuppy',
#  'GAP_scientific_name': 'Necturus maculosus',
#  'GAP_species_code': 'aMUDPx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 208249,
#  'SGCN_common_name': u'Mudpuppy',
#  'SGCN_id': u'Necturus maculosus maculosus'}
#
# 		Kentucky Warbler
# {'GAP-ITIS_TSN': 178937,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Kentucky Warbler',
#  'GAP_scientific_name': 'Oporornis formosus',
#  'GAP_species_code': 'bKEWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950025,
#  'SGCN_common_name': u'Kentucky Warbler',
#  'SGCN_id': u'Geothlypis formosa'}
#
# 		Eastern Fox Squirrel
# {'GAP-ITIS_TSN': 180172,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Eastern Fox Squirrel',
#  'GAP_scientific_name': 'Sciurus niger',
#  'GAP_species_code': 'mEFSQx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 930499,
#  'SGCN_common_name': u'Eastern Fox Squirrel',
#  'SGCN_id': u'Sciurus niger vulpinus'}
#
# 		Purple Finch
# {'GAP-ITIS_TSN': 179186,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Purple Finch',
#  'GAP_scientific_name': 'Carpodacus purpureus',
#  'GAP_species_code': 'bPUFIx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 997803,
#  'SGCN_common_name': u'Purple Finch',
#  'SGCN_id': u'Haemorhous purpureus'}
#
# 		Colima Warbler
# {'GAP-ITIS_TSN': 178865,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Colima Warbler',
#  'GAP_scientific_name': 'Vermivora crissalis',
#  'GAP_species_code': 'bCOLWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950016,
#  'SGCN_common_name': u'Colima Warbler',
#  'SGCN_id': u'Leiothlypis crissalis'}
#
# 		Nashville Warbler
# {'GAP-ITIS_TSN': 178861,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Nashville Warbler',
#  'GAP_scientific_name': 'Vermivora ruficapilla',
#  'GAP_species_code': 'bNAWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950018,
#  'SGCN_common_name': u'Nashville Warbler',
#  'SGCN_id': u'Leiothlypis ruficapilla'}
#
# 		Prairie Warbler
# {'GAP-ITIS_TSN': 178918,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Prairie Warbler',
#  'GAP_scientific_name': 'Dendroica discolor',
#  'GAP_species_code': 'bPRAWx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950052,
#  'SGCN_common_name': u'Prairie Warbler',
#  'SGCN_id': u'Setophaga discolor'}
#
# 		Bay-breasted Warbler
# {'GAP-ITIS_TSN': 178912,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Bay-breasted Warbler',
#  'GAP_scientific_name': 'Dendroica castanea',
#  'GAP_species_code': 'bBBWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950036,
#  'SGCN_common_name': u'Bay-breasted Warbler',
#  'SGCN_id': u'Setophaga castanea'}
#
# 		Piping Plover
# {'GAP-ITIS_TSN': 176507,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Piping Plover',
#  'GAP_scientific_name': 'Charadrius melodus',
#  'GAP_species_code': 'bPIPLx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 176508,
#  'SGCN_common_name': u'Piping Plover',
#  'SGCN_id': u'Charadrius melodus melodus'}
#
# 		Magnolia Warbler
# {'GAP-ITIS_TSN': 178886,
#  'GAP-ITIS_match_notes': 'ITIS valid match.',
#  'GAP_common_name': u'Magnolia Warbler',
#  'GAP_scientific_name': 'Dendroica magnolia',
#  'GAP_species_code': 'bMAWAx',
#  'GAP_taxa_notes': nan,
#  'SGCN-GAP_match_basis': 'common name',
#  'SGCN-GAP_match_notes': 'exact match',
#  'SGCN-ITIS_TSN': 950035,
#  'SGCN_common_name': u'Magnolia Warbler',
#  'SGCN_id': u'Setophaga magnolia'}

# %% [markdown]
# Show the number of records in each dictionary

# %%
print("SGCN Synthesis documents: " + str(len(list(get_collection_cursor(db='bis', collection='SGCN Synthesis', 
                                                                        query=query, host=host, port=port,
                                                                        username=username, password=password)))))
print("GAP species: 1719")
print("Matches: " + str(len(matches.keys())))
print("Non-matches: " + str(len(non_matches.keys())))
# Out:
# SGCN Synthesis documents: 1425
# GAP species: 1719
# Matches: 1146
# Non-matches: 279

# %% [markdown]
# # Insert matches into bis database as a collection

# %% [markdown]
# Build a list of records to insert

# %%
# Add _id values to matches dictionaries
for j in matches:
    matches[j]["_id"] = j

# Put matches dictionaries into a list for insertion into the SGCN-GAP_matches collection
inserts = [matches[x] for x in matches.keys()][:25]  # NOTE !!!! note the selection of first 25 records, any more throws an error. 
pprint.pprint(inserts)
# Out:
# [{'GAP-ITIS_TSN': 554145,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Stilt Sandpiper',
#   'GAP_scientific_name': 'Calidris himantopus',
#   'GAP_species_code': 'bSTSAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 554145,
#   'SGCN_common_name': u'Stilt Sandpiper',
#   'SGCN_id': u'Calidris himantopus',
#   '_id': u'Calidris himantopus'},
#  {'GAP-ITIS_TSN': 550252,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Southern Torrent Salamander',
#   'GAP_scientific_name': 'Rhyacotriton variegatus',
#   'GAP_species_code': 'aSTOSx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 550252,
#   'SGCN_common_name': u'Southern Torrent Salamander',
#   'SGCN_id': u'Rhyacotriton variegatus',
#   '_id': u'Rhyacotriton variegatus'},
#  {'GAP-ITIS_TSN': 180008,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Big Brown Bat',
#   'GAP_scientific_name': 'Eptesicus fuscus',
#   'GAP_species_code': 'mBBBAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 180008,
#   'SGCN_common_name': u'big brown bat',
#   'SGCN_id': u'Eptesicus fuscus',
#   '_id': u'Eptesicus fuscus'},
#  {'GAP-ITIS_TSN': 173654,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u"Dunn's Salamander",
#   'GAP_scientific_name': 'Plethodon dunni',
#   'GAP_species_code': 'aDUSAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 173654,
#   'SGCN_common_name': u"Dunn's Salamander",
#   'SGCN_id': u'Plethodon dunni',
#   '_id': u'Plethodon dunni'},
#  {'GAP-ITIS_TSN': 173449,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Foothill Yellow-legged Frog',
#   'GAP_scientific_name': 'Rana boylii',
#   'GAP_species_code': 'aFYLFx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 173449,
#   'SGCN_common_name': u'Foothill Yellow-legged Frog',
#   'SGCN_id': u'Rana boylii',
#   '_id': u'Rana boylii'},
#  {'GAP-ITIS_TSN': 177828,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Mangrove Cuckoo',
#   'GAP_scientific_name': 'Coccyzus minor',
#   'GAP_species_code': 'bMACUx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 177828,
#   'SGCN_common_name': u'Mangrove Cuckoo',
#   'SGCN_id': u'Coccyzus minor',
#   '_id': u'Coccyzus minor'},
#  {'GAP-ITIS_TSN': 175604,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Peregrine Falcon',
#   'GAP_scientific_name': 'Falco peregrinus',
#   'GAP_species_code': 'bPEFAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 175604,
#   'SGCN_common_name': u'Peregrine Falcon',
#   'SGCN_id': u'Falco peregrinus',
#   '_id': u'Falco peregrinus'},
#  {'GAP-ITIS_TSN': 773527,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Red-spotted Toad',
#   'GAP_scientific_name': 'Anaxyrus punctatus',
#   'GAP_species_code': 'aRSTOx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 773527,
#   'SGCN_common_name': u'Red-spotted Toad',
#   'SGCN_id': u'Anaxyrus punctatus',
#   '_id': u'Anaxyrus punctatus'},
#  {'GAP-ITIS_TSN': 180018,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Southern Yellow Bat',
#   'GAP_scientific_name': 'Lasiurus ega',
#   'GAP_species_code': 'mSYBAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 180018,
#   'SGCN_common_name': u'southern yellow bat',
#   'SGCN_id': u'Lasiurus ega',
#   '_id': u'Lasiurus ega'},
#  {'GAP-ITIS_TSN': 174041,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Western Banded Gecko',
#   'GAP_scientific_name': 'Coleonyx variegatus',
#   'GAP_species_code': 'rWBGEx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 174041,
#   'SGCN_common_name': u'Western Banded Gecko',
#   'SGCN_id': u'Coleonyx variegatus',
#   '_id': u'Coleonyx variegatus'},
#  {'GAP-ITIS_TSN': 180120,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Marsh Rabbit',
#   'GAP_scientific_name': 'Sylvilagus palustris',
#   'GAP_species_code': 'mMARAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 180120,
#   'SGCN_common_name': u'Marsh Rabbit',
#   'SGCN_id': u'Sylvilagus palustris',
#   '_id': u'Sylvilagus palustris'},
#  {'GAP-ITIS_TSN': 176890,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Arctic Tern',
#   'GAP_scientific_name': 'Sterna paradisaea',
#   'GAP_species_code': 'bARTEx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 176890,
#   'SGCN_common_name': u'Arctic Tern',
#   'SGCN_id': u'Sterna paradisaea',
#   '_id': u'Sterna paradisaea'},
#  {'GAP-ITIS_TSN': 931247,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Mangrove Fox Squirrel',
#   'GAP_scientific_name': 'Sciurus niger avicennia',
#   'GAP_species_code': 'mEFSQa',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 931247,
#   'SGCN_common_name': u'Big Cypress fox squirrel',
#   'SGCN_id': u'Sciurus niger avicennia',
#   '_id': u'Sciurus niger avicennia'},
#  {'GAP-ITIS_TSN': 175834,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Greater Prairie-chicken',
#   'GAP_scientific_name': 'Tympanuchus cupido',
#   'GAP_species_code': 'bGRPCx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 175834,
#   'SGCN_common_name': u'Greater Prairie-Chicken',
#   'SGCN_id': u'Tympanuchus cupido',
#   '_id': u'Tympanuchus cupido'},
#  {'GAP-ITIS_TSN': 180549,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'North American River Otter',
#   'GAP_scientific_name': 'Lontra canadensis',
#   'GAP_species_code': 'mNAROx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 180549,
#   'SGCN_common_name': u'North American River Otter',
#   'SGCN_id': u'Lontra canadensis',
#   '_id': u'Lontra canadensis'},
#  {'GAP-ITIS_TSN': 178986,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Painted Redstart',
#   'GAP_scientific_name': 'Myioborus pictus',
#   'GAP_species_code': 'bPAREx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 178986,
#   'SGCN_common_name': u'Painted Redstart',
#   'SGCN_id': u'Myioborus pictus',
#   '_id': u'Myioborus pictus'},
#  {'GAP-ITIS_TSN': 180086,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Big Free-tailed Bat',
#   'GAP_scientific_name': 'Nyctinomops macrotis',
#   'GAP_species_code': 'mBFTBx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 180086,
#   'SGCN_common_name': u'big free-tailed bat',
#   'SGCN_id': u'Nyctinomops macrotis',
#   '_id': u'Nyctinomops macrotis'},
#  {'GAP-ITIS_TSN': 174505,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Pied-billed Grebe',
#   'GAP_scientific_name': 'Podilymbus podiceps',
#   'GAP_species_code': 'bPBGRx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 174505,
#   'SGCN_common_name': u'Pied-billed Grebe',
#   'SGCN_id': u'Podilymbus podiceps',
#   '_id': u'Podilymbus podiceps'},
#  {'GAP-ITIS_TSN': 564574,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Dunes Sagebrush Lizard',
#   'GAP_scientific_name': 'Sceloporus arenicolus',
#   'GAP_species_code': 'rDSALx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 564574,
#   'SGCN_common_name': u'Dunes Sagebrush Lizard',
#   'SGCN_id': u'Sceloporus arenicolus',
#   '_id': u'Sceloporus arenicolus'},
#  {'GAP-ITIS_TSN': 668293,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Jollyville Plateau Salamander',
#   'GAP_scientific_name': 'Eurycea tonkawae',
#   'GAP_species_code': 'aJPSAx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 668293,
#   'SGCN_common_name': u'Jollyville Plateau Salamander',
#   'SGCN_id': u'Eurycea tonkawae',
#   '_id': u'Eurycea tonkawae'},
#  {'GAP-ITIS_TSN': 178436,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Bank Swallow',
#   'GAP_scientific_name': 'Riparia riparia',
#   'GAP_species_code': 'bBANSx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 178436,
#   'SGCN_common_name': u'Bank Swallow',
#   'SGCN_id': u'Riparia riparia',
#   '_id': u'Riparia riparia'},
#  {'GAP-ITIS_TSN': 825084,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'California Least Tern',
#   'GAP_scientific_name': 'Sternula antillarum browni',
#   'GAP_species_code': 'bLETEb',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 825084,
#   'SGCN_common_name': u'California Least Tern',
#   'SGCN_id': u'Sternula antillarum browni',
#   '_id': u'Sternula antillarum browni'},
#  {'GAP-ITIS_TSN': 554447,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Black Skimmer',
#   'GAP_scientific_name': 'Rynchops niger',
#   'GAP_species_code': 'bBLSKx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 554447,
#   'SGCN_common_name': u'Black Skimmer',
#   'SGCN_id': u'Rynchops niger',
#   '_id': u'Rynchops niger'},
#  {'GAP-ITIS_TSN': 775105,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Relict Leopard Frog',
#   'GAP_scientific_name': 'Lithobates onca',
#   'GAP_species_code': 'aRLFRx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 775105,
#   'SGCN_common_name': u'Relict Leopard Frog',
#   'SGCN_id': u'Lithobates onca',
#   '_id': u'Lithobates onca'},
#  {'GAP-ITIS_TSN': 175449,
#   'GAP-ITIS_match_notes': 'ITIS valid match.',
#   'GAP_common_name': u'Hook-billed Kite',
#   'GAP_scientific_name': 'Chondrohierax uncinatus',
#   'GAP_species_code': 'bHBKIx',
#   'GAP_taxa_notes': nan,
#   'SGCN-GAP_match_basis': 'TSN',
#   'SGCN-GAP_match_notes': 'exact match',
#   'SGCN-ITIS_TSN': 175449,
#   'SGCN_common_name': u'Hook-billed Kite',
#   'SGCN_id': u'Chondrohierax uncinatus',
#   '_id': u'Chondrohierax uncinatus'}]

# %% [markdown]
# Insert the records
# ### NOTE: This doesn't work unless the length of the inserts list is < 26.  Why????/

# %%
# Get a connection to the database so records can be inserted
mongo_uri = 'mongodb://%s:%s@%s:%s/%s' % (username, password, host, port, "bis")
client = pymongo.MongoClient(mongo_uri)
bisdb = client.bis
collection = bisdb['SGCN-GAP_matches']

# Insert the records
y = collection.insert_many(inserts)

del client

# %% [markdown]
# # Non-matches

# %%
pprint.pprint(non_matches)
# Out:
# {u'Acris blanchardi': {'SGCN-ITIS_TSN': 774220,
#                        'SGCN_common_name': u"Blanchard's cricket frog",
#                        'SGCN_scientific_name': u'Acris blanchardi'},
#  u'Agkistrodon contortrix mokasen': {'SGCN-ITIS_TSN': 174297,
#                                      'SGCN_common_name': u'Northern Copperhead',
#                                      'SGCN_scientific_name': u'Agkistrodon contortrix mokasen'},
#  u'Agkistrodon piscivorus leucostoma': {'SGCN-ITIS_TSN': 209504,
#                                         'SGCN_common_name': u'Western Cottonmouth',
#                                         'SGCN_scientific_name': u'Agkistrodon piscivorus leucostoma'},
#  u'Amazona viridigenalis': {'SGCN-ITIS_TSN': 177806,
#                             'SGCN_common_name': u'Red-crowned Amazon',
#                             'SGCN_scientific_name': u'Amazona viridigenalis'},
#  u'Ambystoma macrodactylum croceum': {'SGCN-ITIS_TSN': 195693,
#                                       'SGCN_common_name': u'Santa Cruz Long-toed Salamander',
#                                       'SGCN_scientific_name': u'Ambystoma macrodactylum croceum'},
#  u'Ambystoma mavortium nebulosum': {'SGCN-ITIS_TSN': 668589,
#                                     'SGCN_common_name': u'Arizona Tiger Salamander',
#                                     'SGCN_scientific_name': u'Ambystoma mavortium nebulosum'},
#  u'Ambystoma mavortium stebbinsi': {'SGCN-ITIS_TSN': 668592,
#                                     'SGCN_common_name': u'Sonoran Tiger Salamander',
#                                     'SGCN_scientific_name': u'Ambystoma mavortium stebbinsi'},
#  u'Ammodramus maritimus fisheri': {'SGCN-ITIS_TSN': 202317,
#                                    'SGCN_common_name': u'Louisiana Seaside Sparrow',
#                                    'SGCN_scientific_name': u'Ammodramus maritimus fisheri'},
#  u'Ammodramus maritimus macgillivraii': {'SGCN-ITIS_TSN': 202313,
#                                          'SGCN_common_name': u"Seaside Sparrow (McGillivray's)",
#                                          'SGCN_scientific_name': u'Ammodramus maritimus macgillivraii'},
#  u'Ammodramus maritimus mirabilis': {'SGCN-ITIS_TSN': 202311,
#                                      'SGCN_common_name': u'Cape Sable Seaside Sparrow',
#                                      'SGCN_scientific_name': u'Ammodramus maritimus mirabilis'},
#  u'Ammodramus maritimus peninsulae': {'SGCN-ITIS_TSN': 202315,
#                                       'SGCN_common_name': u"Scott's Seaside Sparrow",
#                                       'SGCN_scientific_name': u'Ammodramus maritimus peninsulae'},
#  u'Ammodramus savannarum ammolegus': {'SGCN-ITIS_TSN': 179337,
#                                       'SGCN_common_name': u'Arizona Grasshopper Sparrow',
#                                       'SGCN_scientific_name': u'Ammodramus savannarum ammolegus'},
#  u'Ammodramus savannarum perpallidus': {'SGCN-ITIS_TSN': 179336,
#                                         'SGCN_common_name': u'Western Grasshopper Sparrow',
#                                         'SGCN_scientific_name': u'Ammodramus savannarum perpallidus'},
#  u'Ammospermophilus leucurus tersus': {'SGCN-ITIS_TSN': 930992,
#                                        'SGCN_common_name': u'Prospect Valley White-tailed Antelope Squirrel',
#                                        'SGCN_scientific_name': u'Ammospermophilus leucurus tersus'},
#  u'Anaxyrus boreas boreas': {'SGCN-ITIS_TSN': 776686,
#                              'SGCN_common_name': u'Boreal Toad',
#                              'SGCN_scientific_name': u'Anaxyrus boreas boreas'},
#  u'Anaxyrus woodhousii woodhousii': {'SGCN-ITIS_TSN': 776698,
#                                      'SGCN_common_name': u'Rocky Mountain Toad',
#                                      'SGCN_scientific_name': u'Anaxyrus woodhousii woodhousii'},
#  u'Antilocapra americana americana': {'SGCN-ITIS_TSN': 202417,
#                                       'SGCN_common_name': u'America Pronghorn',
#                                       'SGCN_scientific_name': u'Antilocapra americana americana'},
#  u'Apalone spinifera aspera': {'SGCN-ITIS_TSN': 208683,
#                                'SGCN_common_name': u'Gulf Coast Spiny Softshell Turtle',
#                                'SGCN_scientific_name': u'Apalone spinifera aspera'},
#  u'Apalone spinifera spinifera': {'SGCN-ITIS_TSN': 208693,
#                                   'SGCN_common_name': u'Northern Spiny Softshell Turtle',
#                                   'SGCN_scientific_name': u'Apalone spinifera spinifera'},
#  u'Ardea herodias occidentalis': {'SGCN-ITIS_TSN': 174780,
#                                   'SGCN_common_name': u'Great White Heron',
#                                   'SGCN_scientific_name': u'Ardea herodias occidentalis'},
#  u'Balaenoptera borealis': {'SGCN-ITIS_TSN': 180526,
#                             'SGCN_common_name': u'Sei Whale',
#                             'SGCN_scientific_name': u'Balaenoptera borealis'},
#  u'Balaenoptera musculus': {'SGCN-ITIS_TSN': 180528,
#                             'SGCN_common_name': u'Blue Whale',
#                             'SGCN_scientific_name': u'Balaenoptera musculus'},
#  u'Balaenoptera physalus': {'SGCN-ITIS_TSN': 180527,
#                             'SGCN_common_name': u'Fin Whale',
#                             'SGCN_scientific_name': u'Balaenoptera physalus'},
#  u'Batrachoseps major aridus': {'SGCN-ITIS_TSN': 776872,
#                                 'SGCN_common_name': u'Desert Slender Salamander',
#                                 'SGCN_scientific_name': u'Batrachoseps major aridus'},
#  u'Blarina hylophaga plumbea': {'SGCN-ITIS_TSN': 709900,
#                                 'SGCN_common_name': u'Aransas short-tailed shrew',
#                                 'SGCN_scientific_name': u'Blarina hylophaga plumbea'},
#  u'Branta bernicla nigricans': {'SGCN-ITIS_TSN': 714723,
#                                 'SGCN_common_name': u'Pacific Black Brant',
#                                 'SGCN_scientific_name': u'Branta bernicla nigricans'},
#  u'Branta canadensis occidentalis': {'SGCN-ITIS_TSN': 175006,
#                                      'SGCN_common_name': u'Dusky Canada Goose',
#                                      'SGCN_scientific_name': u'Branta canadensis occidentalis'},
#  u'Calidris bairdii': {'SGCN-ITIS_TSN': 176655,
#                        'SGCN_common_name': u"Baird's Sandpiper",
#                        'SGCN_scientific_name': u'Calidris bairdii'},
#  u'Calidris canutus rufa': {'SGCN-ITIS_TSN': 176644,
#                             'SGCN_common_name': u'red knot',
#                             'SGCN_scientific_name': u'Calidris canutus rufa'},
#  u'Calidris fuscicollis': {'SGCN-ITIS_TSN': 176654,
#                            'SGCN_common_name': u'White-rumped Sandpiper',
#                            'SGCN_scientific_name': u'Calidris fuscicollis'},
#  u'Calidris melanotos': {'SGCN-ITIS_TSN': 176653,
#                          'SGCN_common_name': u'Pectoral Sandpiper',
#                          'SGCN_scientific_name': u'Calidris melanotos'},
#  u'Calidris pusilla': {'SGCN-ITIS_TSN': 176667,
#                        'SGCN_common_name': u'Semipalmated Sandpiper',
#                        'SGCN_scientific_name': u'Calidris pusilla'},
#  u'Calonectris diomedea': {'SGCN-ITIS_TSN': 203446,
#                            'SGCN_common_name': u"Cory's Shearwater",
#                            'SGCN_scientific_name': u'Calonectris diomedea'},
#  u'Campephilus principalis': {'SGCN-ITIS_TSN': 178264,
#                               'SGCN_common_name': u'Ivory-billed Woodpecker',
#                               'SGCN_scientific_name': u'Campephilus principalis'},
#  u'Campylorhynchus brunneicapillus sandiegensis': {'SGCN-ITIS_TSN': 917698,
#                                                    'SGCN_common_name': u'coastal cactus wren (San Diego and Orange Counties)',
#                                                    'SGCN_scientific_name': u'Campylorhynchus brunneicapillus sandiegensis'},
#  u'Canis': {'SGCN-ITIS_TSN': 180595,
#             'SGCN_common_name': u'dogs',
#             'SGCN_scientific_name': u'Canis'},
#  u'Carphophis amoenus amoenus': {'SGCN-ITIS_TSN': 174162,
#                                  'SGCN_common_name': u'Eastern Worm Snake',
#                                  'SGCN_scientific_name': u'Carphophis amoenus amoenus'},
#  u'Catharus minimus': {'SGCN-ITIS_TSN': 179793,
#                        'SGCN_common_name': u'Gray-cheeked Thrush',
#                        'SGCN_scientific_name': u'Catharus minimus'},
#  u'Cemophora coccinea copei': {'SGCN-ITIS_TSN': 174196,
#                                'SGCN_common_name': u'Northern Scarlet Snake',
#                                'SGCN_scientific_name': u'Cemophora coccinea copei'},
#  u'Chionactis occipitalis klauberi': {'SGCN-ITIS_TSN': 209279,
#                                       'SGCN_common_name': u'Tucson Shovel-nosed Snake',
#                                       'SGCN_scientific_name': u'Chionactis occipitalis klauberi'},
#  u'Chrysemys picta bellii': {'SGCN-ITIS_TSN': 208620,
#                              'SGCN_common_name': u'Western Painted Turtle',
#                              'SGCN_scientific_name': u'Chrysemys picta bellii'},
#  u'Chrysemys picta picta': {'SGCN-ITIS_TSN': 173784,
#                             'SGCN_common_name': u'Eastern Painted Turtle',
#                             'SGCN_scientific_name': u'Chrysemys picta picta'},
#  u'Cistothorus palustris griseus': {'SGCN-ITIS_TSN': 726175,
#                                     'SGCN_common_name': u"Worthington's Marsh Wren",
#                                     'SGCN_scientific_name': u'Cistothorus palustris griseus'},
#  u'Cistothorus palustris marianae': {'SGCN-ITIS_TSN': 726176,
#                                      'SGCN_common_name': u"Marian's Marsh Wren",
#                                      'SGCN_scientific_name': u'Cistothorus palustris marianae'},
#  u'Cnemidophorus tigris stejnegeri': {'SGCN-ITIS_TSN': 914117,
#                                       'SGCN_common_name': u'Coastal Western Whiptail',
#                                       'SGCN_scientific_name': u'Cnemidophorus tigris stejnegeri'},
#  u'Coleonyx variegatus abbotti': {'SGCN-ITIS_TSN': 208973,
#                                   'SGCN_common_name': u'San Diego Banded Gecko',
#                                   'SGCN_scientific_name': u'Coleonyx variegatus abbotti'},
#  u'Coleonyx variegatus utahensis': {'SGCN-ITIS_TSN': 208975,
#                                     'SGCN_common_name': u'Utah Banded Gecko',
#                                     'SGCN_scientific_name': u'Coleonyx variegatus utahensis'},
#  u'Colinus virginianus ridgwayi': {'SGCN-ITIS_TSN': 175868,
#                                    'SGCN_common_name': u'Masked Bobwhite',
#                                    'SGCN_scientific_name': u'Colinus virginianus ridgwayi'},
#  u'Coluber constrictor constrictor': {'SGCN-ITIS_TSN': 174170,
#                                       'SGCN_common_name': u'Northern Black Racer',
#                                       'SGCN_scientific_name': u'Coluber constrictor constrictor'},
#  u'Coluber constrictor flaviventris': {'SGCN-ITIS_TSN': 209193,
#                                        'SGCN_common_name': u'Eastern Yellowbelly Racer',
#                                        'SGCN_scientific_name': u'Coluber constrictor flaviventris'},
#  u'Coluber constrictor foxii': {'SGCN-ITIS_TSN': 914123,
#                                 'SGCN_common_name': u'Blue Racer',
#                                 'SGCN_scientific_name': u'Coluber constrictor foxii'},
#  u'Coluber mormon': {'SGCN-ITIS_TSN': 209198,
#                      'SGCN_common_name': u'Western Yellow-bellied Racer',
#                      'SGCN_scientific_name': u'Coluber mormon'},
#  u'Condylura cristata nigra': {'SGCN-ITIS_TSN': 709905,
#                                'SGCN_common_name': u'Southeastern star-nosed mole',
#                                'SGCN_scientific_name': u'Condylura cristata nigra'},
#  u'Conepatus leuconotus leuconotus': {'SGCN-ITIS_TSN': 727368,
#                                       'SGCN_common_name': u'Hog-nosed Skunk',
#                                       'SGCN_scientific_name': u'Conepatus leuconotus leuconotus'},
#  u'Corynorhinus rafinesquii macrotis': {'SGCN-ITIS_TSN': 948486,
#                                         'SGCN_common_name': u'Eastern Big-eared Bat',
#                                         'SGCN_scientific_name': u'Corynorhinus rafinesquii macrotis'},
#  u'Craugastor augusti latrans': {'SGCN-ITIS_TSN': 776749,
#                                  'SGCN_common_name': u'Balcones Barking Frog',
#                                  'SGCN_scientific_name': u'Craugastor augusti latrans'},
#  u'Crotalus oreganus concolor': {'SGCN-ITIS_TSN': 683064,
#                                  'SGCN_common_name': u'Midget Faded Rattlesnake',
#                                  'SGCN_scientific_name': u'Crotalus oreganus concolor'},
#  u'Crotalus willardi obscurus': {'SGCN-ITIS_TSN': 202178,
#                                  'SGCN_common_name': u'Animas Ridge-nosed Rattlesnake',
#                                  'SGCN_scientific_name': u'Crotalus willardi obscurus'},
#  u'Deirochelys reticularia miaria': {'SGCN-ITIS_TSN': 208628,
#                                      'SGCN_common_name': u'Western Chicken Turtle',
#                                      'SGCN_scientific_name': u'Deirochelys reticularia miaria'},
#  u'Desmognathus': {'SGCN-ITIS_TSN': 173632,
#                    'SGCN_common_name': u'Dusky Salamanders',
#                    'SGCN_scientific_name': u'Desmognathus'},
#  u'Diadophis punctatus acricus': {'SGCN-ITIS_TSN': 209168,
#                                   'SGCN_common_name': u'Key Ringneck Snake',
#                                   'SGCN_scientific_name': u'Diadophis punctatus acricus'},
#  u'Diadophis punctatus arnyi': {'SGCN-ITIS_TSN': 209170,
#                                 'SGCN_common_name': u'Prairie Ringneck Snake',
#                                 'SGCN_scientific_name': u'Diadophis punctatus arnyi'},
#  u'Diadophis punctatus edwardsii': {'SGCN-ITIS_TSN': 209171,
#                                     'SGCN_common_name': u'Northern Ringneck Snake',
#                                     'SGCN_scientific_name': u'Diadophis punctatus edwardsii'},
#  u'Dipodomys californicus eximius': {'SGCN-ITIS_TSN': 900659,
#                                      'SGCN_common_name': u'Marysville California Kangaroo Rat',
#                                      'SGCN_scientific_name': u'Dipodomys californicus eximius'},
#  u'Dipodomys compactus compactus': {'SGCN-ITIS_TSN': 900661,
#                                     'SGCN_common_name': u'Padre Island Kangaroo Rat',
#                                     'SGCN_scientific_name': u'Dipodomys compactus compactus'},
#  u'Dipodomys heermanni berkeleyensis': {'SGCN-ITIS_TSN': 900668,
#                                         'SGCN_common_name': u'Berkeley Kangaroo Rat',
#                                         'SGCN_scientific_name': u'Dipodomys heermanni berkeleyensis'},
#  u'Dipodomys heermanni dixoni': {'SGCN-ITIS_TSN': 900669,
#                                  'SGCN_common_name': u'Merced Kangaroo Rat',
#                                  'SGCN_scientific_name': u'Dipodomys heermanni dixoni'},
#  u'Dipodomys merriami collinus': {'SGCN-ITIS_TSN': 900679,
#                                   'SGCN_common_name': u"Earthquake Merriam's Kangaroo Rat",
#                                   'SGCN_scientific_name': u'Dipodomys merriami collinus'},
#  u'Dipodomys merriami parvus': {'SGCN-ITIS_TSN': 625244,
#                                 'SGCN_common_name': u'San Bernardino kangaroo rat',
#                                 'SGCN_scientific_name': u'Dipodomys merriami parvus'},
#  u'Dipodomys microps leucotis': {'SGCN-ITIS_TSN': 625246,
#                                  'SGCN_common_name': u'Marble Canyon kangaroo rat',
#                                  'SGCN_scientific_name': u'Dipodomys microps leucotis'},
#  u'Elaphe guttata': {'SGCN-ITIS_TSN': 174175,
#                      'SGCN_common_name': u'Corn Snake',
#                      'SGCN_scientific_name': u'Elaphe guttata'},
#  u'Elgaria coerulea palmeri': {'SGCN-ITIS_TSN': 209010,
#                                'SGCN_common_name': u'Sierra Alligator Lizard',
#                                'SGCN_scientific_name': u'Elgaria coerulea palmeri'},
#  u'Elgaria coerulea shastensis': {'SGCN-ITIS_TSN': 209016,
#                                   'SGCN_common_name': u'Shasta Alligator Lizard',
#                                   'SGCN_scientific_name': u'Elgaria coerulea shastensis'},
#  u'Empidonax fulvifrons pygmaeus': {'SGCN-ITIS_TSN': 178353,
#                                     'SGCN_common_name': u'Northern Buff-breasted Flycatcher',
#                                     'SGCN_scientific_name': u'Empidonax fulvifrons pygmaeus'},
#  u'Empidonax traillii adastus': {'SGCN-ITIS_TSN': 712528,
#                                  'SGCN_common_name': u'Great Basin Willow Flycatcher',
#                                  'SGCN_scientific_name': u'Empidonax traillii adastus'},
#  u'Empidonax traillii brewsteri': {'SGCN-ITIS_TSN': 178342,
#                                    'SGCN_common_name': u'Sierra Nevada Mountain Willow Flycatcher',
#                                    'SGCN_scientific_name': u'Empidonax traillii brewsteri'},
#  u'Empidonax traillii extimus': {'SGCN-ITIS_TSN': 712529,
#                                  'SGCN_common_name': u'Southwestern willow flycatcher',
#                                  'SGCN_scientific_name': u'Empidonax traillii extimus'},
#  u'Enhydra lutris nereis': {'SGCN-ITIS_TSN': 202390,
#                             'SGCN_common_name': u'southern sea otter',
#                             'SGCN_scientific_name': u'Enhydra lutris nereis'},
#  u'Eremophila alpestris strigata': {'SGCN-ITIS_TSN': 178412,
#                                     'SGCN_common_name': u'streaked horned lark',
#                                     'SGCN_scientific_name': u'Eremophila alpestris strigata'},
#  u'Eubalaena glacialis': {'SGCN-ITIS_TSN': 180537,
#                           'SGCN_common_name': u'North Atlantic Right Whale',
#                           'SGCN_scientific_name': u'Eubalaena glacialis'},
#  u'Eumeces anthracinus pluvialis': {'SGCN-ITIS_TSN': 208884,
#                                     'SGCN_common_name': u'Southern Coal Skink',
#                                     'SGCN_scientific_name': u'Eumeces anthracinus pluvialis'},
#  u'Eumops perotis californicus': {'SGCN-ITIS_TSN': 948314,
#                                   'SGCN_common_name': u'Greater Western Mastiff Bat',
#                                   'SGCN_scientific_name': u'Eumops perotis californicus'},
#  u'Eurycea': {'SGCN-ITIS_TSN': 173684,
#               'SGCN_common_name': u'Brook Salamanders',
#               'SGCN_scientific_name': u'Eurycea'},
#  u'Eurycea longicauda longicauda': {'SGCN-ITIS_TSN': 208310,
#                                     'SGCN_common_name': u'Longtail Salamander',
#                                     'SGCN_scientific_name': u'Eurycea longicauda longicauda'},
#  u'Falco femoralis septentrionalis': {'SGCN-ITIS_TSN': 175611,
#                                       'SGCN_common_name': u'Northern Aplomado Falcon',
#                                       'SGCN_scientific_name': u'Falco femoralis septentrionalis'},
#  u'Falco peregrinus anatum': {'SGCN-ITIS_TSN': 175605,
#                               'SGCN_common_name': u'American Peregrine Falcon',
#                               'SGCN_scientific_name': u'Falco peregrinus anatum'},
#  u'Farancia abacura abacura': {'SGCN-ITIS_TSN': 174165,
#                                'SGCN_common_name': u'Eastern Mud Snake',
#                                'SGCN_scientific_name': u'Farancia abacura abacura'},
#  u'Farancia abacura reinwardtii': {'SGCN-ITIS_TSN': 209185,
#                                    'SGCN_common_name': u'Western Mud Snake',
#                                    'SGCN_scientific_name': u'Farancia abacura reinwardtii'},
#  u'Feresa attenuata': {'SGCN-ITIS_TSN': 180461,
#                        'SGCN_common_name': u'Pygmy Killer Whale',
#                        'SGCN_scientific_name': u'Feresa attenuata'},
#  u'Geomys bursarius ozarkensis': {'SGCN-ITIS_TSN': 900253,
#                                   'SGCN_common_name': u'Ozark Pocket Gopher',
#                                   'SGCN_scientific_name': u'Geomys bursarius ozarkensis'},
#  u'Geomys personatus davisi': {'SGCN-ITIS_TSN': 900256,
#                                'SGCN_common_name': u"Texas (Davis') pocket gopher",
#                                'SGCN_scientific_name': u'Geomys personatus davisi'},
#  u'Geomys personatus maritimus': {'SGCN-ITIS_TSN': 900259,
#                                   'SGCN_common_name': u'Maritime Texas pocket gopher',
#                                   'SGCN_scientific_name': u'Geomys personatus maritimus'},
#  u'Geomys personatus personatus': {'SGCN-ITIS_TSN': 900255,
#                                    'SGCN_common_name': u'Barrier island Texas pocket gopher',
#                                    'SGCN_scientific_name': u'Geomys personatus personatus'},
#  u'Geomys personatus streckeri': {'SGCN-ITIS_TSN': 900261,
#                                   'SGCN_common_name': u'Carrizo Springs Texas pocket gopher',
#                                   'SGCN_scientific_name': u'Geomys personatus streckeri'},
#  u'Geomys texensis bakeri': {'SGCN-ITIS_TSN': 900269,
#                              'SGCN_common_name': u"Baker's Llano pocket gopher",
#                              'SGCN_scientific_name': u'Geomys texensis bakeri'},
#  u'Geomys texensis texensis': {'SGCN-ITIS_TSN': 900268,
#                                'SGCN_common_name': u'Llano pocket gopher',
#                                'SGCN_scientific_name': u'Geomys texensis texensis'},
#  u'Geothlypis tolmiei': {'SGCN-ITIS_TSN': 950023,
#                          'SGCN_common_name': u"MacGillivray's Warbler",
#                          'SGCN_scientific_name': u'Geothlypis tolmiei'},
#  u'Geothlypis trichas sinuosa': {'SGCN-ITIS_TSN': 178954,
#                                  'SGCN_common_name': u'saltmarsh common yellowthroat/San Francisco common yellowthroat',
#                                  'SGCN_scientific_name': u'Geothlypis trichas sinuosa'},
#  u'Globicephala macrorhynchus': {'SGCN-ITIS_TSN': 180466,
#                                  'SGCN_common_name': u'Short-finned Pilot Whale',
#                                  'SGCN_scientific_name': u'Globicephala macrorhynchus'},
#  u'Graptemys pseudogeographica kohnii': {'SGCN-ITIS_TSN': 668678,
#                                          'SGCN_common_name': u'Mississippi Map Turtle',
#                                          'SGCN_scientific_name': u'Graptemys pseudogeographica kohnii'},
#  u'Grus canadensis pratensis': {'SGCN-ITIS_TSN': 176180,
#                                 'SGCN_common_name': u'Florida Sandhill Crane',
#                                 'SGCN_scientific_name': u'Grus canadensis pratensis'},
#  u'Grus canadensis pulla': {'SGCN-ITIS_TSN': 202247,
#                             'SGCN_common_name': u'Mississippi Sandhill Crane',
#                             'SGCN_scientific_name': u'Grus canadensis pulla'},
#  u'Grus canadensis tabida': {'SGCN-ITIS_TSN': 176179,
#                              'SGCN_common_name': u'Sandhill Crane (Greater)',
#                              'SGCN_scientific_name': u'Grus canadensis tabida'},
#  u'Gyrinophilus palleucus necturoides': {'SGCN-ITIS_TSN': 208347,
#                                          'SGCN_common_name': u'Big Mouth Cave Salamander',
#                                          'SGCN_scientific_name': u'Gyrinophilus palleucus necturoides'},
#  u'Gyrinophilus porphyriticus duryi': {'SGCN-ITIS_TSN': 208353,
#                                        'SGCN_common_name': u'Kentucky Spring Salamander',
#                                        'SGCN_scientific_name': u'Gyrinophilus porphyriticus duryi'},
#  u'Gyrinophilus porphyriticus porphyriticus': {'SGCN-ITIS_TSN': 208355,
#                                                'SGCN_common_name': u'Northern Spring Salamander',
#                                                'SGCN_scientific_name': u'Gyrinophilus porphyriticus porphyriticus'},
#  u'Heloderma suspectum suspectum': {'SGCN-ITIS_TSN': 209034,
#                                     'SGCN_common_name': u'Reticulate Gila Monster',
#                                     'SGCN_scientific_name': u'Heloderma suspectum suspectum'},
#  u'Hyla avivoca avivoca': {'SGCN-ITIS_TSN': 776780,
#                            'SGCN_common_name': u'Western Bird-voiced Treefrog',
#                            'SGCN_scientific_name': u'Hyla avivoca avivoca'},
#  u'Ixobrychus exilis exilis': {'SGCN-ITIS_TSN': 174847,
#                                'SGCN_common_name': u'Western Least Bittern',
#                                'SGCN_scientific_name': u'Ixobrychus exilis exilis'},
#  u'Junco hyemalis aikeni': {'SGCN-ITIS_TSN': 179411,
#                             'SGCN_common_name': u'White-winged Junco',
#                             'SGCN_scientific_name': u'Junco hyemalis aikeni'},
#  u'Kogia breviceps': {'SGCN-ITIS_TSN': 180491,
#                       'SGCN_common_name': u'Pygmy Sperm Whale',
#                       'SGCN_scientific_name': u'Kogia breviceps'},
#  u'Kogia sima': {'SGCN-ITIS_TSN': 180492,
#                  'SGCN_common_name': u'Dwarf Sperm Whale',
#                  'SGCN_scientific_name': u'Kogia sima'},
#  u'Lampropeltis calligaster calligaster': {'SGCN-ITIS_TSN': 209221,
#                                            'SGCN_common_name': u'Prairie Kingsnake',
#                                            'SGCN_scientific_name': u'Lampropeltis calligaster calligaster'},
#  u'Lampropeltis calligaster rhombomaculata': {'SGCN-ITIS_TSN': 174186,
#                                               'SGCN_common_name': u'Mole Kingsnake',
#                                               'SGCN_scientific_name': u'Lampropeltis calligaster rhombomaculata'},
#  u'Lampropeltis getula getula': {'SGCN-ITIS_TSN': 174190,
#                                  'SGCN_common_name': u'Eastern Kingsnake',
#                                  'SGCN_scientific_name': u'Lampropeltis getula getula'},
#  u'Lampropeltis getula nigra': {'SGCN-ITIS_TSN': 209251,
#                                 'SGCN_common_name': u'Black Kingsnake',
#                                 'SGCN_scientific_name': u'Lampropeltis getula nigra'},
#  u'Lampropeltis getula nigrita': {'SGCN-ITIS_TSN': 209252,
#                                   'SGCN_common_name': u'Black Desert Kingsnake',
#                                   'SGCN_scientific_name': u'Lampropeltis getula nigrita'},
#  u'Lampropeltis getula sticticeps': {'SGCN-ITIS_TSN': 209254,
#                                      'SGCN_common_name': u'Outer Banks Kingsnake',
#                                      'SGCN_scientific_name': u'Lampropeltis getula sticticeps'},
#  u'Lampropeltis triangulum amaura': {'SGCN-ITIS_TSN': 209225,
#                                      'SGCN_common_name': u'Louisiana Milk Snake',
#                                      'SGCN_scientific_name': u'Lampropeltis triangulum amaura'},
#  u'Lampropeltis triangulum elapsoides': {'SGCN-ITIS_TSN': 209232,
#                                          'SGCN_common_name': u'Scarlet Kingsnake',
#                                          'SGCN_scientific_name': u'Lampropeltis triangulum elapsoides'},
#  u'Lampropeltis triangulum multistriata': {'SGCN-ITIS_TSN': 209237,
#                                            'SGCN_common_name': u'Pale Milk Snake',
#                                            'SGCN_scientific_name': u'Lampropeltis triangulum multistriata'},
#  u'Lampropeltis triangulum syspila': {'SGCN-ITIS_TSN': 209238,
#                                       'SGCN_common_name': u'Red Milk Snake',
#                                       'SGCN_scientific_name': u'Lampropeltis triangulum syspila'},
#  u'Lampropeltis triangulum taylori': {'SGCN-ITIS_TSN': 209241,
#                                       'SGCN_common_name': u'Utah Milk Snake',
#                                       'SGCN_scientific_name': u'Lampropeltis triangulum taylori'},
#  u'Lanius ludovicianus mearnsi': {'SGCN-ITIS_TSN': 178522,
#                                   'SGCN_common_name': u'San Clemente Loggerhead Shrike',
#                                   'SGCN_scientific_name': u'Lanius ludovicianus mearnsi'},
#  u'Lanius ludovicianus migrans': {'SGCN-ITIS_TSN': 178516,
#                                   'SGCN_common_name': u'Migrant loggerhead shrike',
#                                   'SGCN_scientific_name': u'Lanius ludovicianus migrans'},
#  u'Leptonycteris yerbabuenae': {'SGCN-ITIS_TSN': 202347,
#                                 'SGCN_common_name': u'lesser long-nosed bat',
#                                 'SGCN_scientific_name': u'Leptonycteris yerbabuenae'},
#  u'Lepus americanus cascadensis': {'SGCN-ITIS_TSN': 727811,
#                                    'SGCN_common_name': u'Sierra Nevada snowshoe hare',
#                                    'SGCN_scientific_name': u'Lepus americanus cascadensis'},
#  u'Limosa haemastica': {'SGCN-ITIS_TSN': 176690,
#                         'SGCN_common_name': u'Hudsonian Godwit',
#                         'SGCN_scientific_name': u'Limosa haemastica'},
#  u'Lithobates areolatus areolatus': {'SGCN-ITIS_TSN': 776826,
#                                      'SGCN_common_name': u'Southern Crawfish Frog',
#                                      'SGCN_scientific_name': u'Lithobates areolatus areolatus'},
#  u'Lithobates areolatus circulosus': {'SGCN-ITIS_TSN': 776827,
#                                       'SGCN_common_name': u'Northern Crawfish Frog',
#                                       'SGCN_scientific_name': u'Lithobates areolatus circulosus'},
#  u'Lithobates sphenocephalus sphenocephalus': {'SGCN-ITIS_TSN': 776839,
#                                                'SGCN_common_name': u'Florida Leopard Frog',
#                                                'SGCN_scientific_name': u'Lithobates sphenocephalus sphenocephalus'},
#  u'Lithobates tarahumarae': {'SGCN-ITIS_TSN': 775118,
#                              'SGCN_common_name': u'Tarahumara Frog',
#                              'SGCN_scientific_name': u'Lithobates tarahumarae'},
#  u'Lontra canadensis lataxina': {'SGCN-ITIS_TSN': 727011,
#                                  'SGCN_common_name': u'River Otter',
#                                  'SGCN_scientific_name': u'Lontra canadensis lataxina'},
#  u'Lontra canadensis sonora': {'SGCN-ITIS_TSN': 727015,
#                                'SGCN_common_name': u'southwestern otter',
#                                'SGCN_scientific_name': u'Lontra canadensis sonora'},
#  u'Malaclemys terrapin pileata': {'SGCN-ITIS_TSN': 208613,
#                                   'SGCN_common_name': u'Mississippi Diamondback Terrapin',
#                                   'SGCN_scientific_name': u'Malaclemys terrapin pileata'},
#  u'Malaclemys terrapin terrapin': {'SGCN-ITIS_TSN': 173781,
#                                    'SGCN_common_name': u'Northern Diamondback Terrapin',
#                                    'SGCN_scientific_name': u'Malaclemys terrapin terrapin'},
#  u'Masticophis flagellum flagellum': {'SGCN-ITIS_TSN': 209322,
#                                       'SGCN_common_name': u'Eastern Coachwhip',
#                                       'SGCN_scientific_name': u'Masticophis flagellum flagellum'},
#  u'Megaptera novaeangliae': {'SGCN-ITIS_TSN': 180530,
#                              'SGCN_common_name': u'Humpback Whale',
#                              'SGCN_scientific_name': u'Megaptera novaeangliae'},
#  u'Melospiza georgiana georgiana': {'SGCN-ITIS_TSN': 179490,
#                                     'SGCN_common_name': u'Southern Swamp Sparrow',
#                                     'SGCN_scientific_name': u'Melospiza georgiana georgiana'},
#  u'Melospiza melodia maxillaris': {'SGCN-ITIS_TSN': 179511,
#                                    'SGCN_common_name': u'Suisun song sparrow',
#                                    'SGCN_scientific_name': u'Melospiza melodia maxillaris'},
#  u'Melospiza melodia pusillula': {'SGCN-ITIS_TSN': 179513,
#                                   'SGCN_common_name': u'Alameda song sparrow',
#                                   'SGCN_scientific_name': u'Melospiza melodia pusillula'},
#  u'Melospiza melodia samuelis': {'SGCN-ITIS_TSN': 179512,
#                                  'SGCN_common_name': u'San Pablo (= Samuels) song sparrow',
#                                  'SGCN_scientific_name': u'Melospiza melodia samuelis'},
#  u'Melozone crissalis eremophila': {'SGCN-ITIS_TSN': 998093,
#                                     'SGCN_common_name': u'Inyo California Towhee',
#                                     'SGCN_scientific_name': u'Melozone crissalis eremophila'},
#  u'Mesoplodon europaeus': {'SGCN-ITIS_TSN': 180509,
#                            'SGCN_common_name': u"Gervais' Beaked Whale",
#                            'SGCN_scientific_name': u'Mesoplodon europaeus'},
#  u'Microtus mexicanus': {'SGCN-ITIS_TSN': 180308,
#                          'SGCN_common_name': u'Mexican Vole',
#                          'SGCN_scientific_name': u'Microtus mexicanus'},
#  u'Morus bassanus': {'SGCN-ITIS_TSN': 174712,
#                      'SGCN_common_name': u'Northern Gannet',
#                      'SGCN_scientific_name': u'Morus bassanus'},
#  u'Mustela frenata olivacea': {'SGCN-ITIS_TSN': 727264,
#                                'SGCN_common_name': u'Southeastern Weasel',
#                                'SGCN_scientific_name': u'Mustela frenata olivacea'},
#  u'Mustela frenata peninsulae': {'SGCN-ITIS_TSN': 727268,
#                                  'SGCN_common_name': u'Florida Long-tailed Weasel',
#                                  'SGCN_scientific_name': u'Mustela frenata peninsulae'},
#  u'Myotis thysanodes pahasapensis': {'SGCN-ITIS_TSN': 948622,
#                                      'SGCN_common_name': u'Fringe-tailed Myotis',
#                                      'SGCN_scientific_name': u'Myotis thysanodes pahasapensis'},
#  u'Necturus maculosus louisianensis': {'SGCN-ITIS_TSN': 208250,
#                                        'SGCN_common_name': u'Red River Waterdog',
#                                        'SGCN_scientific_name': u'Necturus maculosus louisianensis'},
#  u'Neovison vison evergladensis': {'SGCN-ITIS_TSN': 727333,
#                                    'SGCN_common_name': u'Everglades Mink',
#                                    'SGCN_scientific_name': u'Neovison vison evergladensis'},
#  u'Neovison vison halilimnetes': {'SGCN-ITIS_TSN': 933394,
#                                   'SGCN_common_name': u'Gulf Salt Marsh Mink',
#                                   'SGCN_scientific_name': u'Neovison vison halilimnetes'},
#  u'Neovison vison lutensis': {'SGCN-ITIS_TSN': 727338,
#                               'SGCN_common_name': u'Atlantic Salt Marsh Mink',
#                               'SGCN_scientific_name': u'Neovison vison lutensis'},
#  u'Nerodia clarkii clarkii': {'SGCN-ITIS_TSN': 209372,
#                               'SGCN_common_name': u'Gulf Salt Marsh Snake',
#                               'SGCN_scientific_name': u'Nerodia clarkii clarkii'},
#  u'Nerodia clarkii compressicauda': {'SGCN-ITIS_TSN': 209373,
#                                      'SGCN_common_name': u'Mangrove Salt Marsh Snake',
#                                      'SGCN_scientific_name': u'Nerodia clarkii compressicauda'},
#  u'Nerodia clarkii taeniata': {'SGCN-ITIS_TSN': 209380,
#                                'SGCN_common_name': u'Atlantic Salt Marsh Snake',
#                                'SGCN_scientific_name': u'Nerodia clarkii taeniata'},
#  u'Nerodia erythrogaster flavigaster': {'SGCN-ITIS_TSN': 209341,
#                                         'SGCN_common_name': u'Yellow-bellied Water Snake',
#                                         'SGCN_scientific_name': u'Nerodia erythrogaster flavigaster'},
#  u'Nerodia erythrogaster neglecta': {'SGCN-ITIS_TSN': 209343,
#                                      'SGCN_common_name': u'Copperbelly Water Snake',
#                                      'SGCN_scientific_name': u'Nerodia erythrogaster neglecta'},
#  u'Nerodia fasciata confluens': {'SGCN-ITIS_TSN': 209351,
#                                  'SGCN_common_name': u'Broad-banded Water Snake',
#                                  'SGCN_scientific_name': u'Nerodia fasciata confluens'},
#  u'Nerodia rhombifer rhombifer': {'SGCN-ITIS_TSN': 563942,
#                                   'SGCN_common_name': u'Diamondback Water Snake',
#                                   'SGCN_scientific_name': u'Nerodia rhombifer rhombifer'},
#  u'Nerodia sipedon insularum': {'SGCN-ITIS_TSN': 209363,
#                                 'SGCN_common_name': u'Lake Erie Water Snake',
#                                 'SGCN_scientific_name': u'Nerodia sipedon insularum'},
#  u'Nerodia sipedon williamengelsi': {'SGCN-ITIS_TSN': 209368,
#                                      'SGCN_common_name': u'Carolina Water Snake',
#                                      'SGCN_scientific_name': u'Nerodia sipedon williamengelsi'},
#  u'Numenius borealis': {'SGCN-ITIS_TSN': 176605,
#                         'SGCN_common_name': u'Eskimo Curlew',
#                         'SGCN_scientific_name': u'Numenius borealis'},
#  u'Oceanodroma melania': {'SGCN-ITIS_TSN': 174640,
#                           'SGCN_common_name': u'Black Storm Petrel',
#                           'SGCN_scientific_name': u'Oceanodroma melania'},
#  u'Odocoileus virginianus couesi': {'SGCN-ITIS_TSN': 898469,
#                                     'SGCN_common_name': u"Coues' White-tailed Deer",
#                                     'SGCN_scientific_name': u'Odocoileus virginianus couesi'},
#  u'Ophisaurus attenuatus attenuatus': {'SGCN-ITIS_TSN': 174107,
#                                        'SGCN_common_name': u'Western Slender Glass Lizard',
#                                        'SGCN_scientific_name': u'Ophisaurus attenuatus attenuatus'},
#  u'Ophisaurus attenuatus longicaudus': {'SGCN-ITIS_TSN': 174108,
#                                         'SGCN_common_name': u'Eastern Slender Glass Lizard',
#                                         'SGCN_scientific_name': u'Ophisaurus attenuatus longicaudus'},
#  u'Orcinus orca': {'SGCN-ITIS_TSN': 180469,
#                    'SGCN_common_name': u'Killer Whale',
#                    'SGCN_scientific_name': u'Orcinus orca'},
#  u'Ovis canadensis canadensis': {'SGCN-ITIS_TSN': 898801,
#                                  'SGCN_common_name': u'Rocky Mountain bighorn sheep',
#                                  'SGCN_scientific_name': u'Ovis canadensis canadensis'},
#  u'Ovis canadensis mexicana': {'SGCN-ITIS_TSN': 898804,
#                                'SGCN_common_name': u'desert bighorn sheep',
#                                'SGCN_scientific_name': u'Ovis canadensis mexicana'},
#  u'Ovis canadensis nelsoni': {'SGCN-ITIS_TSN': 898805,
#                               'SGCN_common_name': u"Nelson's bighorn sheep",
#                               'SGCN_scientific_name': u'Ovis canadensis nelsoni'},
#  u'Passerculus sandwichensis beldingi': {'SGCN-ITIS_TSN': 179325,
#                                          'SGCN_common_name': u'Belding\xe2\x80\x99s savannah sparrow',
#                                          'SGCN_scientific_name': u'Passerculus sandwichensis beldingi'},
#  u'Passerculus sandwichensis princeps': {'SGCN-ITIS_TSN': 179315,
#                                          'SGCN_common_name': u'Ipswich Sparrow',
#                                          'SGCN_scientific_name': u'Passerculus sandwichensis princeps'},
#  u'Passerculus sandwichensis rostratus': {'SGCN-ITIS_TSN': 179330,
#                                           'SGCN_common_name': u'Large-billed Sparrow',
#                                           'SGCN_scientific_name': u'Passerculus sandwichensis rostratus'},
#  u'Perimyotis subflavus': {'SGCN-ITIS_TSN': 947299,
#                            'SGCN_common_name': u'Tricolored Bat',
#                            'SGCN_scientific_name': u'Perimyotis subflavus'},
#  u'Perognathus alticolus inexpectatus': {'SGCN-ITIS_TSN': 900886,
#                                          'SGCN_common_name': u'Tehachapi Pocket Mouse',
#                                          'SGCN_scientific_name': u'Perognathus alticolus inexpectatus'},
#  u'Perognathus flavescens melanotis': {'SGCN-ITIS_TSN': 900898,
#                                        'SGCN_common_name': u'Apache pocket mouse',
#                                        'SGCN_scientific_name': u'Perognathus flavescens melanotis'},
#  u'Perognathus flavus goodpasteri': {'SGCN-ITIS_TSN': 900906,
#                                      'SGCN_common_name': u'Springerville Pocket Mouse',
#                                      'SGCN_scientific_name': u'Perognathus flavus goodpasteri'},
#  u'Perognathus longimembris bangsi': {'SGCN-ITIS_TSN': 900920,
#                                       'SGCN_common_name': u'Palm Springs Pocket Mouse',
#                                       'SGCN_scientific_name': u'Perognathus longimembris bangsi'},
#  u'Perognathus longimembris brevinasus': {'SGCN-ITIS_TSN': 900922,
#                                           'SGCN_common_name': u'Los Angeles Pocket Mouse',
#                                           'SGCN_scientific_name': u'Perognathus longimembris brevinasus'},
#  u'Perognathus longimembris internationalis': {'SGCN-ITIS_TSN': 900924,
#                                                'SGCN_common_name': u'Jacumba Pocket Mouse',
#                                                'SGCN_scientific_name': u'Perognathus longimembris internationalis'},
#  u'Perognathus parvus xanthonotus': {'SGCN-ITIS_TSN': 625254,
#                                      'SGCN_common_name': u'Yellow-eared Pocket Mouse',
#                                      'SGCN_scientific_name': u'Perognathus parvus xanthonotus'},
#  u'Phalaropus lobatus': {'SGCN-ITIS_TSN': 176735,
#                          'SGCN_common_name': u'Red-necked Phalarope',
#                          'SGCN_scientific_name': u'Phalaropus lobatus'},
#  u'Phocoena phocoena': {'SGCN-ITIS_TSN': 180473,
#                         'SGCN_common_name': u'Harbor Porpoise',
#                         'SGCN_scientific_name': u'Phocoena phocoena'},
#  u'Physeter macrocephalus': {'SGCN-ITIS_TSN': 180488,
#                              'SGCN_common_name': u'Sperm Whale',
#                              'SGCN_scientific_name': u'Physeter macrocephalus'},
#  u'Picoides tridactylus': {'SGCN-ITIS_TSN': 178251,
#                            'SGCN_common_name': u'Three-toed Woodpecker',
#                            'SGCN_scientific_name': u'Picoides tridactylus'},
#  u'Pipilo maculatus clementae': {'SGCN-ITIS_TSN': 730448,
#                                  'SGCN_common_name': u'San Clemente (Spotted) Towhee',
#                                  'SGCN_scientific_name': u'Pipilo maculatus clementae'},
#  u'Pituophis catenifer deserticola': {'SGCN-ITIS_TSN': 209407,
#                                       'SGCN_common_name': u'Great Basin Gopher Snake',
#                                       'SGCN_scientific_name': u'Pituophis catenifer deserticola'},
#  u'Pituophis catenifer sayi': {'SGCN-ITIS_TSN': 209409,
#                                'SGCN_common_name': u'Bullsnake',
#                                'SGCN_scientific_name': u'Pituophis catenifer sayi'},
#  u'Pituophis melanoleucus melanoleucus': {'SGCN-ITIS_TSN': 209397,
#                                           'SGCN_common_name': u'Northern Pine Snake',
#                                           'SGCN_scientific_name': u'Pituophis melanoleucus melanoleucus'},
#  u'Pluvialis dominica': {'SGCN-ITIS_TSN': 176564,
#                          'SGCN_common_name': u'Lesser Golden-Plover',
#                          'SGCN_scientific_name': u'Pluvialis dominica'},
#  u'Polioptila californica californica': {'SGCN-ITIS_TSN': 925072,
#                                          'SGCN_common_name': u'coastal California gnatcatcher',
#                                          'SGCN_scientific_name': u'Polioptila californica californica'},
#  u'Polioptila nigriceps': {'SGCN-ITIS_TSN': 179863,
#                            'SGCN_common_name': u'Black-capped Gnatcatcher',
#                            'SGCN_scientific_name': u'Polioptila nigriceps'},
#  u'Procyon lotor auspicatus': {'SGCN-ITIS_TSN': 727464,
#                                'SGCN_common_name': u'Key Vaca Raccoon',
#                                'SGCN_scientific_name': u'Procyon lotor auspicatus'},
#  u'Procyon lotor incautus': {'SGCN-ITIS_TSN': 727472,
#                              'SGCN_common_name': u'Key West Raccoon',
#                              'SGCN_scientific_name': u'Procyon lotor incautus'},
#  u'Progne subis arboricola': {'SGCN-ITIS_TSN': 924850,
#                               'SGCN_common_name': u'Western Purple Martin',
#                               'SGCN_scientific_name': u'Progne subis arboricola'},
#  u'Progne subis hesperia': {'SGCN-ITIS_TSN': 178466,
#                             'SGCN_common_name': u'Desert Purple Martin',
#                             'SGCN_scientific_name': u'Progne subis hesperia'},
#  u'Pseudemys concinna floridana': {'SGCN-ITIS_TSN': 551965,
#                                    'SGCN_common_name': u'Florida cooter',
#                                    'SGCN_scientific_name': u'Pseudemys concinna floridana'},
#  u'Pseudemys concinna suwanniensis': {'SGCN-ITIS_TSN': 208646,
#                                       'SGCN_common_name': u'Suwannee River cooter',
#                                       'SGCN_scientific_name': u'Pseudemys concinna suwanniensis'},
#  u'Pseudobranchus striatus lustricolus': {'SGCN-ITIS_TSN': 208504,
#                                           'SGCN_common_name': u'Gulf Hammock Mud Siren',
#                                           'SGCN_scientific_name': u'Pseudobranchus striatus lustricolus'},
#  u'Pseudobranchus striatus striatus': {'SGCN-ITIS_TSN': 208502,
#                                        'SGCN_common_name': u'Broad-striped Mud Siren',
#                                        'SGCN_scientific_name': u'Pseudobranchus striatus striatus'},
#  u'Pseudorca crassidens': {'SGCN-ITIS_TSN': 180463,
#                            'SGCN_common_name': u'False Killer Whale',
#                            'SGCN_scientific_name': u'Pseudorca crassidens'},
#  u'Pseudotriton diastictus': {'SGCN-ITIS_TSN': 775914,
#                               'SGCN_common_name': u'Midland Mud Salamander',
#                               'SGCN_scientific_name': u'Pseudotriton diastictus'},
#  u'Pseudotriton montanus flavissimus': {'SGCN-ITIS_TSN': 208303,
#                                         'SGCN_common_name': u'Gulf Coast Mud Salamander',
#                                         'SGCN_scientific_name': u'Pseudotriton montanus flavissimus'},
#  u'Pseudotriton montanus montanus': {'SGCN-ITIS_TSN': 173683,
#                                      'SGCN_common_name': u'Eastern Mud Salamander',
#                                      'SGCN_scientific_name': u'Pseudotriton montanus montanus'},
#  u'Pseudotriton ruber ruber': {'SGCN-ITIS_TSN': 173681,
#                                'SGCN_common_name': u'Northern Red Salamander',
#                                'SGCN_scientific_name': u'Pseudotriton ruber ruber'},
#  u'Pseudotriton ruber vioscai': {'SGCN-ITIS_TSN': 208301,
#                                  'SGCN_common_name': u'Southern Red Salamander',
#                                  'SGCN_scientific_name': u'Pseudotriton ruber vioscai'},
#  u'Puffinus gravis': {'SGCN-ITIS_TSN': 174549,
#                       'SGCN_common_name': u'Greater Shearwater',
#                       'SGCN_scientific_name': u'Puffinus gravis'},
#  u'Puffinus lherminieri': {'SGCN-ITIS_TSN': 174561,
#                            'SGCN_common_name': u"Audubon's Shearwater",
#                            'SGCN_scientific_name': u'Puffinus lherminieri'},
#  u'Puma concolor couguar': {'SGCN-ITIS_TSN': 622093,
#                             'SGCN_common_name': u'eastern cougar',
#                             'SGCN_scientific_name': u'Puma concolor couguar'},
#  u'Rallus longirostris insularum': {'SGCN-ITIS_TSN': 176218,
#                                     'SGCN_common_name': u'Mangrove Clapper Rail',
#                                     'SGCN_scientific_name': u'Rallus longirostris insularum'},
#  u'Rallus longirostris scottii': {'SGCN-ITIS_TSN': 708006,
#                                   'SGCN_common_name': u'Florida Clapper Rail',
#                                   'SGCN_scientific_name': u'Rallus longirostris scottii'},
#  u'Rallus longirostris yumanensis': {'SGCN-ITIS_TSN': 176214,
#                                      'SGCN_common_name': u'Yuma Clapper Rail',
#                                      'SGCN_scientific_name': u'Rallus longirostris yumanensis'},
#  u'Regina rigida deltae': {'SGCN-ITIS_TSN': 209071,
#                            'SGCN_common_name': u'Delta Crawfish Snake',
#                            'SGCN_scientific_name': u'Regina rigida deltae'},
#  u'Regina rigida rigida': {'SGCN-ITIS_TSN': 174124,
#                            'SGCN_common_name': u'Glossy Crawfish Snake',
#                            'SGCN_scientific_name': u'Regina rigida rigida'},
#  u'Regina rigida sinicola': {'SGCN-ITIS_TSN': 209072,
#                              'SGCN_common_name': u'Gulf Crawfish Snake',
#                              'SGCN_scientific_name': u'Regina rigida sinicola'},
#  u'Rhinocheilus lecontei tessellatus': {'SGCN-ITIS_TSN': 209414,
#                                         'SGCN_common_name': u'Texas Long-nosed Snake',
#                                         'SGCN_scientific_name': u'Rhinocheilus lecontei tessellatus'},
#  u'Rhynchophanes mccownii': {'SGCN-ITIS_TSN': 997873,
#                              'SGCN_common_name': u"McCown's Longspur",
#                              'SGCN_scientific_name': u'Rhynchophanes mccownii'},
#  u'Rhynchopsitta pachyrhyncha': {'SGCN-ITIS_TSN': 177411,
#                                  'SGCN_common_name': u'Thick-billed Parrot',
#                                  'SGCN_scientific_name': u'Rhynchopsitta pachyrhyncha'},
#  u'Salvadora hexalepis virgultea': {'SGCN-ITIS_TSN': 209420,
#                                     'SGCN_common_name': u'Coast Patchnose Snake',
#                                     'SGCN_scientific_name': u'Salvadora hexalepis virgultea'},
#  u'Scapanus latimanus parvus': {'SGCN-ITIS_TSN': 710016,
#                                 'SGCN_common_name': u'Alameda Island mole',
#                                 'SGCN_scientific_name': u'Scapanus latimanus parvus'},
#  u'Sceloporus graciosus graciosus': {'SGCN-ITIS_TSN': 208742,
#                                      'SGCN_common_name': u'Northern Sagebrush Lizard',
#                                      'SGCN_scientific_name': u'Sceloporus graciosus graciosus'},
#  u'Sciurus aberti chuscensis': {'SGCN-ITIS_TSN': 930409,
#                                 'SGCN_common_name': u"Abert's Chuska Squirrel",
#                                 'SGCN_scientific_name': u'Sciurus aberti chuscensis'},
#  u'Sciurus nayaritensis chiricahuae': {'SGCN-ITIS_TSN': 930491,
#                                        'SGCN_common_name': u'Chiricahua Nayarit squirrel',
#                                        'SGCN_scientific_name': u'Sciurus nayaritensis chiricahuae'},
#  u'Sciurus niger niger': {'SGCN-ITIS_TSN': 202357,
#                           'SGCN_common_name': u'fox squirrel',
#                           'SGCN_scientific_name': u'Sciurus niger niger'},
#  u'Sciurus niger shermani': {'SGCN-ITIS_TSN': 930497,
#                              'SGCN_common_name': u"Sherman's fox squirrel",
#                              'SGCN_scientific_name': u'Sciurus niger shermani'},
#  u'Setophaga discolor paludicola': {'SGCN-ITIS_TSN': 950200,
#                                     'SGCN_common_name': u'Florida Prairie Warbler',
#                                     'SGCN_scientific_name': u'Setophaga discolor paludicola'},
#  u'Setophaga dominica stoddardi': {'SGCN-ITIS_TSN': 950195,
#                                    'SGCN_common_name': u"Stoddard's Yellow-throated Warbler",
#                                    'SGCN_scientific_name': u'Setophaga dominica stoddardi'},
#  u'Setophaga nigrescens': {'SGCN-ITIS_TSN': 950057,
#                            'SGCN_common_name': u'Black-throated Grey Warbler',
#                            'SGCN_scientific_name': u'Setophaga nigrescens'},
#  u'Setophaga petechia': {'SGCN-ITIS_TSN': 950039,
#                          'SGCN_common_name': u'Mangrove Warbler',
#                          'SGCN_scientific_name': u'Setophaga petechia'},
#  u'Setophaga petechia gundlachi': {'SGCN-ITIS_TSN': 950170,
#                                    'SGCN_common_name': u'Cuban Yellow Warbler',
#                                    'SGCN_scientific_name': u'Setophaga petechia gundlachi'},
#  u'Sialia sialis fulva': {'SGCN-ITIS_TSN': 179805,
#                           'SGCN_common_name': u'Azure Bluebird',
#                           'SGCN_scientific_name': u'Sialia sialis fulva'},
#  u'Siren': {'SGCN-ITIS_TSN': 773312,
#             'SGCN_common_name': u'Rio Grande Siren (large form)',
#             'SGCN_scientific_name': u'Siren'},
#  u'Siren intermedia intermedia': {'SGCN-ITIS_TSN': 208499,
#                                   'SGCN_common_name': u'Eastern Lesser Siren',
#                                   'SGCN_scientific_name': u'Siren intermedia intermedia'},
#  u'Siren intermedia nettingi': {'SGCN-ITIS_TSN': 208500,
#                                 'SGCN_common_name': u'Western Lesser Siren',
#                                 'SGCN_scientific_name': u'Siren intermedia nettingi'},
#  u'Sistrurus miliarius streckeri': {'SGCN-ITIS_TSN': 209508,
#                                     'SGCN_common_name': u'Western Pigmy Rattlesnake',
#                                     'SGCN_scientific_name': u'Sistrurus miliarius streckeri'},
#  u'Sistrurus tergeminus tergeminus': {'SGCN-ITIS_TSN': 58794,
#                                       'SGCN_common_name': u'Prairie Massasauga',
#                                       'SGCN_scientific_name': u'Sistrurus tergeminus tergeminus'},
#  u'Sitta carolinensis aculeata': {'SGCN-ITIS_TSN': 178779,
#                                   'SGCN_common_name': u'White-breasted Nuthatch (Slender-billed)',
#                                   'SGCN_scientific_name': u'Sitta carolinensis aculeata'},
#  u'Sorex cinereus fontinalis': {'SGCN-ITIS_TSN': 710033,
#                                 'SGCN_common_name': u'Maryland shrew',
#                                 'SGCN_scientific_name': u'Sorex cinereus fontinalis'},
#  u'Sorex dispar blitchi': {'SGCN-ITIS_TSN': 710042,
#                            'SGCN_common_name': u'Long-tailed Or Rock Shrew',
#                            'SGCN_scientific_name': u'Sorex dispar blitchi'},
#  u'Sorex hoyi winnemana': {'SGCN-ITIS_TSN': 710056,
#                            'SGCN_common_name': u'southern pygmy shrew',
#                            'SGCN_scientific_name': u'Sorex hoyi winnemana'},
#  u'Sorex palustris punctulatus': {'SGCN-ITIS_TSN': 710086,
#                                   'SGCN_common_name': u'southern water shrew',
#                                   'SGCN_scientific_name': u'Sorex palustris punctulatus'},
#  u'Spilogale gracilis amphialus': {'SGCN-ITIS_TSN': 727403,
#                                    'SGCN_common_name': u'Channel Islands spotted skunk',
#                                    'SGCN_scientific_name': u'Spilogale gracilis amphialus'},
#  u'Spilogale putorius interrupta': {'SGCN-ITIS_TSN': 727411,
#                                     'SGCN_common_name': u'Plains spotted skunk',
#                                     'SGCN_scientific_name': u'Spilogale putorius interrupta'},
#  u'Stenella frontalis': {'SGCN-ITIS_TSN': 552460,
#                          'SGCN_common_name': u'Atlantic Spotted Dolphin',
#                          'SGCN_scientific_name': u'Stenella frontalis'},
#  u'Steno bredanensis': {'SGCN-ITIS_TSN': 180417,
#                         'SGCN_common_name': u'Rough-toothed Dolphin',
#                         'SGCN_scientific_name': u'Steno bredanensis'},
#  u'Sternotherus minor peltifer': {'SGCN-ITIS_TSN': 208567,
#                                   'SGCN_common_name': u'stripeneck musk turtle',
#                                   'SGCN_scientific_name': u'Sternotherus minor peltifer'},
#  u'Storeria dekayi dekayi': {'SGCN-ITIS_TSN': 174130,
#                              'SGCN_common_name': u'Northern Brown Snake',
#                              'SGCN_scientific_name': u'Storeria dekayi dekayi'},
#  u'Storeria occipitomaculata occipitomaculata': {'SGCN-ITIS_TSN': 174132,
#                                                  'SGCN_common_name': u'Northern Redbelly Snake',
#                                                  'SGCN_scientific_name': u'Storeria occipitomaculata occipitomaculata'},
#  u'Storeria occipitomaculata pahasapae': {'SGCN-ITIS_TSN': 209084,
#                                           'SGCN_common_name': u'Black Hills Redbelly Snake',
#                                           'SGCN_scientific_name': u'Storeria occipitomaculata pahasapae'},
#  u'Sylvilagus bachmani bachmani': {'SGCN-ITIS_TSN': 625376,
#                                    'SGCN_common_name': u'riparian brush rabbit',
#                                    'SGCN_scientific_name': u'Sylvilagus bachmani bachmani'},
#  u'Sylvilagus nuttallii grangeri': {'SGCN-ITIS_TSN': 727986,
#                                     'SGCN_common_name': u'North Kaibab Mountain Cottontail',
#                                     'SGCN_scientific_name': u'Sylvilagus nuttallii grangeri'},
#  u'Sylvilagus nuttallii pinetis': {'SGCN-ITIS_TSN': 727987,
#                                    'SGCN_common_name': u'Southwestern Cottontail',
#                                    'SGCN_scientific_name': u'Sylvilagus nuttallii pinetis'},
#  u'Tamias speciosus speciosus': {'SGCN-ITIS_TSN': 931197,
#                                  'SGCN_common_name': u'lodgepole chipmunk',
#                                  'SGCN_scientific_name': u'Tamias speciosus speciosus'},
#  u'Thamnophis eques megalops': {'SGCN-ITIS_TSN': 209125,
#                                 'SGCN_common_name': u'Northern Mexican Garter Snake',
#                                 'SGCN_scientific_name': u'Thamnophis eques megalops'},
#  u'Thamnophis proximus proximus': {'SGCN-ITIS_TSN': 209135,
#                                    'SGCN_common_name': u'Western Ribbon Snake',
#                                    'SGCN_scientific_name': u'Thamnophis proximus proximus'},
#  u'Thamnophis sauritus sauritus': {'SGCN-ITIS_TSN': 174135,
#                                    'SGCN_common_name': u'Eastern Ribbon Snake',
#                                    'SGCN_scientific_name': u'Thamnophis sauritus sauritus'},
#  u'Thamnophis sauritus septentrionalis': {'SGCN-ITIS_TSN': 209088,
#                                           'SGCN_common_name': u'Northern Ribbon Snake',
#                                           'SGCN_scientific_name': u'Thamnophis sauritus septentrionalis'},
#  u'Thamnophis sirtalis annectens': {'SGCN-ITIS_TSN': 209091,
#                                     'SGCN_common_name': u'Texas Garter Snake',
#                                     'SGCN_scientific_name': u'Thamnophis sirtalis annectens'},
#  u'Thamnophis sirtalis tetrataenia': {'SGCN-ITIS_TSN': 202170,
#                                       'SGCN_common_name': u'San Francisco Garter Snake',
#                                       'SGCN_scientific_name': u'Thamnophis sirtalis tetrataenia'},
#  u'Thomomys bottae rubidus': {'SGCN-ITIS_TSN': 900422,
#                               'SGCN_common_name': u"Botta's pocket gopher (rubidus ssp)",
#                               'SGCN_scientific_name': u'Thomomys bottae rubidus'},
#  u'Thomomys bottae subsimilis': {'SGCN-ITIS_TSN': 900437,
#                                  'SGCN_common_name': u'Harquahala southern pocket gopher',
#                                  'SGCN_scientific_name': u'Thomomys bottae subsimilis'},
#  u'Thomomys talpoides cheyennensis': {'SGCN-ITIS_TSN': 900475,
#                                       'SGCN_common_name': u'Cheyenne Northern Pocket Gopher',
#                                       'SGCN_scientific_name': u'Thomomys talpoides cheyennensis'},
#  u'Trachemys scripta elegans': {'SGCN-ITIS_TSN': 173823,
#                                 'SGCN_common_name': u'Red-eared Slider',
#                                 'SGCN_scientific_name': u'Trachemys scripta elegans'},
#  u'Trachemys scripta scripta': {'SGCN-ITIS_TSN': 173821,
#                                 'SGCN_common_name': u'Yellow-bellied Slider',
#                                 'SGCN_scientific_name': u'Trachemys scripta scripta'},
#  u'Trachemys scripta troostii': {'SGCN-ITIS_TSN': 173825,
#                                  'SGCN_common_name': u'Cumberland Slider',
#                                  'SGCN_scientific_name': u'Trachemys scripta troostii'},
#  u'Trichechus manatus latirostris': {'SGCN-ITIS_TSN': 610165,
#                                      'SGCN_common_name': u'Florida manatee',
#                                      'SGCN_scientific_name': u'Trichechus manatus latirostris'},
#  u'Tryngites subruficollis': {'SGCN-ITIS_TSN': 158972,
#                               'SGCN_common_name': u'Buff-breasted Sandpiper',
#                               'SGCN_scientific_name': u'Tryngites subruficollis'},
#  u'Tursiops truncatus': {'SGCN-ITIS_TSN': 180426,
#                          'SGCN_common_name': u'Bottlenose Dolphin',
#                          'SGCN_scientific_name': u'Tursiops truncatus'},
#  u'Uma': {'SGCN-ITIS_TSN': 173947,
#           'SGCN_common_name': u'Fringe-toed Lizards',
#           'SGCN_scientific_name': u'Uma'},
#  u'Urocitellus townsendii nancyae': {'SGCN-ITIS_TSN': 931108,
#                                      'SGCN_common_name': u"Townsend's ground squirrel ssp.",
#                                      'SGCN_scientific_name': u'Urocitellus townsendii nancyae'},
#  u'Urosaurus ornatus wrighti': {'SGCN-ITIS_TSN': 208858,
#                                 'SGCN_common_name': u'Northern Tree Lizard',
#                                 'SGCN_scientific_name': u'Urosaurus ornatus wrighti'},
#  u'Vermivora bachmanii': {'SGCN-ITIS_TSN': 178854,
#                           'SGCN_common_name': u"Bachman's Warbler",
#                           'SGCN_scientific_name': u'Vermivora bachmanii'},
#  u'Vireo bellii arizonae': {'SGCN-ITIS_TSN': 179006,
#                             'SGCN_common_name': u"Arizona Bell's vireo",
#                             'SGCN_scientific_name': u'Vireo bellii arizonae'},
#  u'Vireo bellii pusillus': {'SGCN-ITIS_TSN': 179007,
#                             'SGCN_common_name': u"Least Bell's Vireo",
#                             'SGCN_scientific_name': u'Vireo bellii pusillus'},
#  u'Virginia valeriae pulchra': {'SGCN-ITIS_TSN': 209159,
#                                 'SGCN_common_name': u'Mountain Earth Snake',
#                                 'SGCN_scientific_name': u'Virginia valeriae pulchra'},
#  u'Virginia valeriae valeriae': {'SGCN-ITIS_TSN': 174152,
#                                  'SGCN_common_name': u'Eastern Earth Snake',
#                                  'SGCN_scientific_name': u'Virginia valeriae valeriae'},
#  u'Xerospermophilus tereticaudus chlorus': {'SGCN-ITIS_TSN': 931243,
#                                             'SGCN_common_name': u'Coachella Valley round-tailed ground squirrel',
#                                             'SGCN_scientific_name': u'Xerospermophilus tereticaudus chlorus'},
#  u'Ziphius cavirostris': {'SGCN-ITIS_TSN': 180498,
#                           'SGCN_common_name': u'goose-beaked whale',
#                           'SGCN_scientific_name': u'Ziphius cavirostris'}}
